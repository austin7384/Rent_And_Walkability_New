# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Downloads/Crimes_-_2001_to_Present.csv')
dfCrime = dfCrime[dfCrime['Arrest']]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (2103645, 22)
#          ID Case Number                    Date                    Block  \
# 0  13311263    JG503434  07/29/2022 03:39:00 AM          023XX S TROY ST
# 1  13053066    JG103252  01/03/2023 04:44:00 PM  039XX W WASHINGTON BLVD
# 7  12729745    JF279458  06/14/2022 02:47:00 PM      035XX N CENTRAL AVE
# 8  12835559    JF406130  09/21/2022 10:00:00 PM          004XX E 69TH ST
# 9  13003649    JG177593  02/22/2023 01:50:00 PM        070XX S CLYDE AVE
#
#    IUCR                Primary Type                     Description  \
# 0  1582  OFFENSE INVOLVING CHILDREN               CHILD PORNOGRAPHY
# 1  2017                   NARCOTICS   MANUFACTURE / DELIVER - CRACK
# 7  0340                     ROBBERY  ATTEMPT STRONG ARM - NO WEAPON
# 8  0910         MOTOR VEHICLE THEFT                      AUTOMOBILE
# 9  0610                    BURGLARY                  FORCIBLE ENTRY
#
#           Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                    RESIDENCE    True     False  ...  25.0            30.0
# 1                     SIDEWALK    True     False  ...  28.0            26.0
# 7                         BANK    True     False  ...  30.0            15.0
# 8              OTHER (SPECIFY)    True     False  ...   6.0            69.0
# 9  RESIDENCE - PORCH / HALLWAY    True     False  ...   5.0            43.0
#
#    FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0        17           NaN          NaN  2022  04/18/2024 03:40:59 PM
# 1        18           NaN          NaN  2023  01/20/2024 03:41:12 PM
# 7        03     1138391.0    1923142.0  2022  01/19/2024 03:40:50 PM
# 8        07     1180204.0    1859359.0  2022  01/19/2024 03:40:50 PM
# 9        05     1191427.0    1858753.0  2023  01/19/2024 03:40:50 PM
#
#     Latitude  Longitude                       Location
# 0        NaN        NaN                            NaN
# 1        NaN        NaN                            NaN
# 7  41.945232 -87.766735  (41.945232412, -87.766734668)
# 8  41.769347 -87.615008  (41.769346711, -87.615008288)
# 9  41.767419 -87.573890  (41.767419224, -87.573890196)
#
# [5 rows x 22 columns]

# %%
dfCrime.dtypes
# Out:
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
dfCrime = dfCrime[dfCrime['Year'] == 2021]
dfCrime = dfCrime[(dfCrime['Latitude'].isna() == False) & (dfCrime['Longitude'].isna() == False)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (25152, 22)
#             ID Case Number                    Date                 Block  \
# 20    12342615    JE202211  04/17/2021 03:20:00 PM   081XX S PRAIRIE AVE
# 84       26262    JE366265  09/08/2021 04:45:00 PM   047XX W HARRISON ST
# 851   12346572    JE206964  04/22/2021 02:30:00 PM       016XX W 59TH ST
# 3365  12358148    JE220723  05/05/2021 03:31:00 PM    005XX W MELROSE ST
# 3366  12379997    JE247919  05/30/2021 01:45:00 PM  021XX W LEXINGTON ST
#
#       IUCR        Primary Type              Description  \
# 20    0325             ROBBERY      VEHICULAR HIJACKING
# 84    0110            HOMICIDE      FIRST DEGREE MURDER
# 851   1140  DECEPTIVE PRACTICE             EMBEZZLEMENT
# 3365  0486             BATTERY  DOMESTIC BATTERY SIMPLE
# 3366  0486             BATTERY  DOMESTIC BATTERY SIMPLE
#
#               Location Description  Arrest  Domestic  ...  Ward  \
# 20                       RESIDENCE    True     False  ...   6.0
# 84                        CAR WASH    True     False  ...  24.0
# 851   COMMERCIAL / BUSINESS OFFICE    True     False  ...  16.0
# 3365                     APARTMENT    True      True  ...  44.0
# 3366                        STREET    True      True  ...  28.0
#
#       Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 20              44.0        03     1179448.0    1851073.0  2021
# 84              25.0       01A     1144907.0    1896933.0  2021
# 851             67.0        12     1166240.0    1865581.0  2021
# 3365             6.0       08B     1172155.0    1921906.0  2021
# 3366            28.0       08B     1162202.0    1896743.0  2021
#
#                   Updated On   Latitude  Longitude  \
# 20    09/14/2023 03:41:59 PM  41.746626 -87.618032
# 84    09/14/2023 03:41:59 PM  41.873191 -87.743447
# 851   04/18/2024 03:40:20 PM  41.786729 -87.666017
# 3365  09/17/2023 03:41:45 PM  41.941161 -87.642668
# 3366  09/17/2023 03:41:45 PM  41.872326 -87.679953
#
#                            Location
# 20    (41.746626309, -87.618031954)
# 84    (41.873191445, -87.743446563)
# 851   (41.786729308, -87.666016839)
# 3365  (41.941161268, -87.642667917)
# 3366  (41.872326358, -87.679953348)
#
# [5 rows x 22 columns]

# %%
violentCrimeCodes = ['03', '01A', '02', '04A', '01B']
dfCrime = dfCrime[dfCrime['FBI Code'].isin(violentCrimeCodes)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (1833, 22)
#              ID Case Number                    Date                Block  \
# 20     12342615    JE202211  04/17/2021 03:20:00 PM  081XX S PRAIRIE AVE
# 84        26262    JE366265  09/08/2021 04:45:00 PM  047XX W HARRISON ST
# 8353   12271626    JE115190  01/17/2021 01:22:00 AM   120XX S NORMAL AVE
# 8362   12467872    JE355873  06/28/2021 05:30:00 PM      011XX S TROY ST
# 15332  12370697    JE236167  05/20/2021 10:09:00 AM  069XX S CRANDON AVE
#
#        IUCR             Primary Type          Description  \
# 20     0325                  ROBBERY  VEHICULAR HIJACKING
# 84     0110                 HOMICIDE  FIRST DEGREE MURDER
# 8353   0266  CRIMINAL SEXUAL ASSAULT            PREDATORY
# 8362   031A                  ROBBERY      ARMED - HANDGUN
# 15332  0325                  ROBBERY  VEHICULAR HIJACKING
#
#       Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 20               RESIDENCE    True     False  ...   6.0            44.0
# 84                CAR WASH    True     False  ...  24.0            25.0
# 8353             RESIDENCE    True      True  ...  21.0            53.0
# 8362              SIDEWALK    True     False  ...  24.0            29.0
# 15332                ALLEY    True     False  ...   5.0            43.0
#
#        FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 20           03     1179448.0    1851073.0  2021  09/14/2023 03:41:59 PM
# 84          01A     1144907.0    1896933.0  2021  09/14/2023 03:41:59 PM
# 8353         02     1175135.0    1825082.0  2021  01/30/2024 03:40:48 PM
# 8362         03     1155533.0    1894990.0  2021  09/22/2023 03:41:26 PM
# 15332        03     1192522.0    1859436.0  2021  06/18/2024 03:40:31 PM
#
#         Latitude  Longitude                       Location
# 20     41.746626 -87.618032  (41.746626309, -87.618031954)
# 84     41.873191 -87.743447  (41.873191445, -87.743446563)
# 8353   41.675401 -87.634609  (41.675400611, -87.634608576)
# 8362   41.867653 -87.704485  (41.867652634, -87.704485374)
# 15332  41.769267 -87.569854  (41.769266826, -87.569854405)
#
# [5 rows x 22 columns]

# %%
dfCrime = dfCrime[['FBI Code', 'Latitude', 'Longitude']]

# make our lon and lat into a point type for spacial join
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
dfCrime = dfCrime[['FBI Code', 'geometry']]
dfCrime.head()
# Out:
#       FBI Code                                 geometry
# 20          03       POINT (-87.618031954 41.746626309)
# 84         01A  POINT (-87.74344656300001 41.873191445)
# 8353        02  POINT (-87.63460857600001 41.675400611)
# 8362        03       POINT (-87.704485374 41.867652634)
# 15332       03       POINT (-87.569854405 41.769266826)

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("cb_2022_us_bg_500k/cb_2022_us_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (242297, 12)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      04      019  940800        2  1500000US040199408002  040199408002    2
# 1      04      003  000901        4  1500000US040030009014  040030009014    4
# 2      06      073  018102        3  1500000US060730181023  060730181023    3
# 3      06      073  007200        3  1500000US060730072003  060730072003    3
# 4      06      073  017702        3  1500000US060730177023  060730177023    3
#
#         NAMELSAD LSAD       ALAND  AWATER  \
# 0  Block Group 2   BG  2033911373   68536
# 1  Block Group 4   BG      486316       0
# 2  Block Group 3   BG      324091    3579
# 3  Block Group 3   BG      720442  709604
# 4  Block Group 3   BG      317237       0
#
#                                             geometry
# 0  POLYGON ((-112.41 31.857, -112.38 31.859, -112...
# 1  POLYGON ((-109.55 31.334, -109.55 31.339, -109...
# 2  POLYGON ((-117.37 33.182, -117.37 33.182, -117...
# 3  POLYGON ((-117.26 32.725, -117.26 32.726, -117...
# 4  POLYGON ((-117.3 33.052, -117.3 33.053, -117.3...

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#       FBI Code                geometry
# 20          03  POINT (-87.618 41.747)
# 84         01A  POINT (-87.743 41.873)
# 8353        02  POINT (-87.635 41.675)
# 8362        03  POINT (-87.704 41.868)
# 15332       03   POINT (-87.57 41.769)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (1833, 14)
#       FBI Code                geometry  index_right STATEFP COUNTYFP TRACTCE  \
# 20          03  POINT (-87.618 41.747)      61382.0      17      031  440300
# 84         01A  POINT (-87.743 41.873)     194628.0      17      031  252202
# 8353        02  POINT (-87.635 41.675)      62144.0      17      031  530501
# 8362        03  POINT (-87.704 41.868)      30829.0      17      031  838600
# 15332       03   POINT (-87.57 41.769)      38770.0      17      031  430102
#
#       BLKGRPCE               AFFGEOID         GEOID NAME       NAMELSAD LSAD  \
# 20           2  1500000US170314403002  170314403002    2  Block Group 2   BG
# 84           3  1500000US170312522023  170312522023    3  Block Group 3   BG
# 8353         2  1500000US170315305012  170315305012    2  Block Group 2   BG
# 8362         1  1500000US170318386001  170318386001    1  Block Group 1   BG
# 15332        3  1500000US170314301023  170314301023    3  Block Group 3   BG
#
#           ALAND  AWATER
# 20     433247.0     0.0
# 84     190165.0     0.0
# 8353   364561.0     0.0
# 8362   123012.0     0.0
# 15332   55027.0     0.0

# %%
crime = result['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US170318391001    22
# 1500000US170313301021    12
# 1500000US170313204001    11
# 1500000US170318370001     9
# 1500000US170318434001     8
#                          ..
# 1500000US170318319001     1
# 1500000US170311911003     1
# 1500000US170312520001     1
# 1500000US170318380002     1
# 1500000US170314208002     1
# Name: count, Length: 1000, dtype: int64

# %%
# export as a csv
crime.to_csv('Chicago_Violent_Crime_BG.csv')
