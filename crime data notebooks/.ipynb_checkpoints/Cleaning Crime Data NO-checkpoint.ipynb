# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from shapely.wkt import loads

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Calls_for_Service_2019_20250428.csv')
print(dfCrime.shape)
dfCrime.head()
# Out:
# (487362, 21)
#   NOPD_Item  Type                     TypeText Priority     MapX    MapY  \
# 0  E3696819   21P                LOST PROPERTY       0G  3682079  532392
# 1  E3711919   34D  AGGRAVATED BATTERY DOMESTIC       2C  3674751  525920
# 2  E3721919   21P                LOST PROPERTY       0G  3681704  531945
# 3  E3724019  103D         DOMESTIC DISTURBANCE       2C  3699162  557853
# 4  E3735719   62C      SIMPLE BURGLARY VEHICLE       1G  3727938  560667
#
#                TimeCreate            TimeDispatch             TimeArrival  \
# 0  05/26/2019 05:08:29 AM  05/26/2019 05:08:29 AM  05/26/2019 05:08:29 AM
# 1  05/26/2019 09:10:51 AM  05/26/2019 09:12:32 AM  05/26/2019 09:21:11 AM
# 2  05/26/2019 10:47:30 AM  05/26/2019 03:46:05 PM  05/26/2019 03:46:10 PM
# 3  05/26/2019 11:12:23 AM  05/26/2019 11:18:05 AM  05/26/2019 11:39:08 AM
# 4  05/26/2019 01:36:51 PM  05/26/2019 05:37:42 PM  05/26/2019 05:37:47 PM
#
#                TimeClosed  ...   DispositionText InitialType  \
# 0  05/26/2019 05:24:02 AM  ...  REPORT TO FOLLOW          21
# 1  05/27/2019 05:49:50 PM  ...  REPORT TO FOLLOW         34S
# 2  05/26/2019 04:42:53 PM  ...  REPORT TO FOLLOW          67
# 3  05/26/2019 01:06:41 PM  ...  REPORT TO FOLLOW        103D
# 4  05/26/2019 06:36:35 PM  ...  REPORT TO FOLLOW         21P
#
#                   InitialTypeText InitialPriority SelfInitiated  Beat  \
# 0                 COMPLAINT OTHER              1J             Y  8D06
# 1  AGGRAVATED BATTERY BY SHOOTING              2C             N  6I02
# 2                           THEFT              1G             N  8D05
# 3            DOMESTIC DISTURBANCE              2C             N  7D06
# 4                   LOST PROPERTY              0G             N  7L02
#
#             BLOCK_ADDRESS      Zip  PoliceDistrict  \
# 0        006XX Bourbon St  70130.0               8
# 1            025XX 2nd St  70113.0               6
# 2    004XX Blk Bourbon St  70112.0               8
# 3         070XX Martin Dr  70126.0               7
# 4  138XX Chef Menteur Hwy  70129.0               7
#
#                       Location
# 0  (29.95787779, -90.06620983)
# 1  (29.94030144, -90.08957166)
# 2  (29.95666057, -90.06741082)
# 3  (30.02735574, -90.01133827)
# 4  (30.03414756, -89.92030106)
#
# [5 rows x 21 columns]

# %%
sorted(list(dfCrime['TypeText'].unique()))
# Out:
# ['ABANDONED BOAT',
#  'ABANDONED VEHICLE',
#  'AGGRAVATED ARSON',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED ASSAULT DOMESTIC',
#  'AGGRAVATED BATTERY',
#  'AGGRAVATED BATTERY BY CUTTING',
#  'AGGRAVATED BATTERY BY SHOOTING',
#  'AGGRAVATED BATTERY DOMESTIC',
#  'AGGRAVATED BURGLARY',
#  'AGGRAVATED BURGLARY DOMESTIC',
#  'AGGRAVATED CRIMINAL DAMAGE',
#  'AGGRAVATED KIDNAPPING',
#  'AGGRAVATED RAPE',
#  'AGGRAVATED RAPE MALE VICTIM',
#  'AGGRAVATED RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE',
#  'AIRPLANE CRASH',
#  'AREA CHECK',
#  'ARMED ROBBERY',
#  'ARMED ROBBERY WITH GUN',
#  'ARMED ROBBERY WITH KNIFE',
#  'ASSET SEIZURE',
#  'ATTACHMENT',
#  'AUTO ACCIDENT',
#  'AUTO ACCIDENT CITY VEHICLE',
#  'AUTO ACCIDENT FATALITY',
#  'AUTO ACCIDENT POLICE VEHICLE',
#  'AUTO ACCIDENT WITH INJURY',
#  'AUTO THEFT',
#  'BICYCLE THEFT',
#  'BLIGHTED PROPERTY',
#  'BOMB SCARE',
#  'BURGLAR ALARM, LOCAL',
#  'BURGLAR ALARM, SILENT',
#  'BURGLAR ALARM, SILENT, FAR NO RESPONSE',
#  'BUSINESS BURGLARY',
#  'BUSINESS CHECK',
#  'CAD TEST',
#  'CARJACKING',
#  'CARJACKING- NO WEAPON',
#  'COMPLAINT OTHER',
#  'CONTRIBUTING TO DELINQUENCY',
#  'CRIME AGAINST NATURE',
#  'CRIMINAL DAMAGE DOMESTIC',
#  'CRIMINAL MISCHIEF',
#  'CRIMINAL MISCHIEF DOMESTIC',
#  'CRUELTY TO ANIMALS',
#  'CURFEW VIOLATION',
#  'DEATH',
#  'DIRECTED PATROL',
#  'DIRECTED TRAFFIC ENFORCEMENT',
#  'DISCHARGING FIREARM',
#  'DISPERSE SUBJECTS',
#  'DISTURBANCE (OTHER)',
#  'DOMESTIC DISTURBANCE',
#  'DRIVING WHILE UNDER INFLUENCE',
#  'DRUG VIOLATIONS',
#  'DRUNK',
#  'EXPLOSION',
#  'EXTORTION (THREATS)',
#  'EXTORTION (THREATS) DOMESTIC',
#  'FIGHT',
#  'FIRE',
#  'FIREWORKS',
#  'FLOOD EVENT',
#  'FLOODED VEHICLE',
#  'FORGERY',
#  'FUGITIVE ATTACHMENT',
#  'HIT & RUN',
#  'HIT & RUN CITY VEHICLE',
#  'HIT & RUN FATALITY',
#  'HIT & RUN POLICE VEHICLE',
#  'HIT & RUN WITH INJURIES',
#  'HOLD UP ALARM',
#  'HOMELESS',
#  'HOMICIDE',
#  'HOMICIDE BY CUTTING',
#  'HOMICIDE BY SHOOTING',
#  'HOMICIDE DOMESTIC',
#  'ILLEGAL CARRYING OF WEAPON',
#  'ILLEGAL CARRYING OF WEAPON- GUN',
#  'ILLEGAL CARRYING OF WEAPON- KNIFE',
#  'IMPERSONATING AN OFFICER',
#  'INCIDENT REQUESTED BY ANOTHER AGENCY',
#  'INDECENT BEHAVIOR',
#  'ISSUING WORTHLESS CHECKS',
#  'JUVENILE ATTACHMENT',
#  'LOST PROPERTY',
#  'MEDICAL',
#  'MEDICAL - NALOXONE',
#  'MEDICAL SEXUAL ASSAULT KIT PROCESSING',
#  'MEET AN OFFICER',
#  'MENTAL PATIENT',
#  'MISDEMEANOR SEXUAL BATTERY',
#  'MISSING ADULT',
#  'MISSING JUVENILE',
#  'MUNICIPAL ATTACHMENT',
#  'NEGLIENT INJURY',
#  'NOISE COMPLAINT',
#  'OBSCENITY, EXPOSING',
#  'OFFICER NEEDS ASSISTANCE',
#  'OFFICER NEEDS ASSISTANCE, LIFE IN DANGER',
#  'ORAL SEXUAL BATTERY',
#  'PARADE ITEM NUMBER',
#  'PEEPING TOM',
#  'PICKPOCKET',
#  'POSSESSION OF STOLEN PROPERTY',
#  'PROSTITUTION',
#  'PROTEST',
#  'PROWLER',
#  'PUBLIC GATHERING',
#  'QUALITY OF LIFE ISSUE',
#  'RECKLESS DRIVING',
#  'RECOVERY OF REPORTED STOLEN VEHICLE',
#  'RECOVERY OF VEHICLE',
#  'RESIDENCE BURGLARY',
#  'RESIDENCE CHECK',
#  'RETURN FOR ADDITIONAL INFO',
#  'SAFE BURGLARY',
#  'SEX OFFENDER REGISTRATION CHECK',
#  'SEXTING',
#  'SEXUAL BATTERY',
#  'SHOPLIFTING',
#  'SILENT 911 CALL',
#  'SIMPLE ARSON',
#  'SIMPLE ARSON DOMESTIC',
#  'SIMPLE ASSAULT',
#  'SIMPLE ASSAULT DOMESTIC',
#  'SIMPLE BATTERY',
#  'SIMPLE BATTERY DOMESTIC',
#  'SIMPLE BURGLARY',
#  'SIMPLE BURGLARY DOMESTIC',
#  'SIMPLE BURGLARY VEHICLE',
#  'SIMPLE CRIMINAL DAMAGE',
#  'SIMPLE ESCAPE',
#  'SIMPLE KIDNAPPING',
#  'SIMPLE RAPE',
#  'SIMPLE RAPE MALE VICTIM',
#  'SIMPLE RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE',
#  'SIMPLE ROBBERY',
#  'SIMPLE ROBBERY, PROPERTY SNATCHING',
#  'SIMULTANEOS STOLEN/RECOVERY VEHICLE',
#  'SOLICITING FOR PROSTITUTION',
#  'SUICIDE',
#  'SUICIDE ATTEMPT',
#  'SUICIDE THREAT',
#  'SUSPICIOUS PACKAGE',
#  'SUSPICIOUS PERSON',
#  'THEFT',
#  'THEFT BY EMBEZZLEMENT',
#  'THEFT BY FRAUD',
#  'THEFT FROM EXTERIOR OF VEHICLE',
#  'TOW IMPOUNDED VEHICLE (PRIVATE)',
#  'TRAFFIC ATTACHMENT',
#  'TRAFFIC CONGESTION',
#  'TRAFFIC INCIDENT',
#  'TRAFFIC STOP',
#  'TROOP N AREA - BUSINESS - RESIDENCE CHECK',
#  'TRUANT VIOLATION',
#  'UNAUTHORIZED USE OF VEHICLE',
#  'UNCLASSIFIED DEATH',
#  'UNDERAGE DRINKING VIOLATION',
#  'UNDERPASS MONITORING OR CLOSURE',
#  'UNLAWFUL SALES TO MINORS',
#  'VEHICLE NO-PURSUIT',
#  'VEHICLE PURSUIT',
#  'VIDEO VOYEURISM',
#  'VIOLATION OF PROTECTION ORDER',
#  'WALKING BEAT',
#  'WARR STOP WITH RELEASE']

# %%
violentCrimes = ['AGGRAVATED ASSAULT', 'AGGRAVATED ASSAULT DOMESTIC', 'AGGRAVATED RAPE', 'AGGRAVATED RAPE MALE VICTIM', 
                 'AGGRAVATED RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE', 'ARMED ROBBERY', 'ARMED ROBBERY WITH GUN', 
                 'ARMED ROBBERY WITH KNIFE', 'HOMICIDE', 'HOMICIDE BY CUTTING', 'HOMICIDE BY SHOOTING', 'HOMICIDE DOMESTIC',
                'SIMPLE RAPE', 'SIMPLE RAPE MALE VICTIM', 'SIMPLE RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE']
propertyCrimes = ['BUSINESS BURGLARY', 'CARJACKING', 'CARJACKING- NO WEAPON',  'RESIDENCE BURGLARY', 'SAFE BURGLARY', 'SIMPLE BURGLARY',
                  'SIMPLE BURGLARY DOMESTIC', 'SIMPLE BURGLARY VEHICLE', 'THEFT', 'THEFT FROM EXTERIOR OF VEHICLE', 'AGGRAVATED BURGLARY',
                  'AGGRAVATED BURGLARY DOMESTIC', 'AUTO THEFT', 'BICYCLE THEFT']
both = violentCrimes + propertyCrimes
dfCrime = dfCrime[dfCrime['TypeText'].isin(both)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (26796, 21)
#    NOPD_Item Type                 TypeText Priority     MapX    MapY  \
# 4   E3735719  62C  SIMPLE BURGLARY VEHICLE       1G  3727938  560667
# 15  E3779419   30                 HOMICIDE       2C  3700961  552103
# 27  E3785919  30S     HOMICIDE BY SHOOTING       2C  3683148  540254
# 28  E3786019  62C  SIMPLE BURGLARY VEHICLE       1G  3676608  549917
# 29  E3787119  62R       RESIDENCE BURGLARY       1E  3695961  526738
#
#                 TimeCreate            TimeDispatch             TimeArrival  \
# 4   05/26/2019 01:36:51 PM  05/26/2019 05:37:42 PM  05/26/2019 05:37:47 PM
# 15  05/26/2019 09:02:13 PM  05/26/2019 09:04:23 PM  05/26/2019 09:04:30 PM
# 27  05/26/2019 09:58:47 PM  05/26/2019 10:00:07 PM  05/26/2019 10:05:44 PM
# 28  05/26/2019 09:59:03 PM  05/26/2019 10:01:17 PM  05/26/2019 10:05:48 PM
# 29  05/26/2019 10:06:26 PM  05/27/2019 01:08:36 AM  05/27/2019 01:14:47 AM
#
#                 TimeClosed  ...   DispositionText InitialType  \
# 4   05/26/2019 06:36:35 PM  ...  REPORT TO FOLLOW         21P
# 15  05/27/2019 12:00:46 AM  ...  REPORT TO FOLLOW          35
# 27  05/27/2019 01:47:39 AM  ...  REPORT TO FOLLOW         34S
# 28  05/27/2019 01:43:24 AM  ...   GONE ON ARRIVAL         67A
# 29  05/27/2019 02:26:57 AM  ...  REPORT TO FOLLOW         62R
#
#                    InitialTypeText InitialPriority SelfInitiated  Beat  \
# 4                    LOST PROPERTY              0G             N  7L02
# 15                  SIMPLE BATTERY              1F             N  7C02
# 27  AGGRAVATED BATTERY BY SHOOTING              2C             N  5K02
# 28                      AUTO THEFT              1D             N  3M05
# 29              RESIDENCE BURGLARY              1E             N  4H02
#
#                       BLOCK_ADDRESS      Zip  PoliceDistrict  \
# 4            138XX Chef Menteur Hwy  70129.0               7
# 15  Chantilly Dr & Chef Menteur Hwy  70126.0               7
# 27           022XX Saint Anthony St  70119.0               5
# 28          048XX Saint Bernard Ave  70122.0               3
# 29                  012XX Odeon Ave  70114.0               4
#
#                        Location
# 4   (30.03414756, -89.92030106)
# 15   (30.01148679, -90.0058646)
# 27  (29.97946128, -90.06256029)
# 28  (30.00622969, -90.08288183)
# 29  (29.94190101, -90.02257831)
#
# [5 rows x 21 columns]

# %%
dfCrime = dfCrime[['TypeText', 'Location']]
dfCrime = dfCrime[dfCrime['Location'] != '(0.0, 0.0)']
dfCrime = dfCrime[dfCrime['Location'].isna() == False]
dfCrime.head()
# Out:
#                    TypeText                     Location
# 4   SIMPLE BURGLARY VEHICLE  (30.03414756, -89.92030106)
# 15                 HOMICIDE   (30.01148679, -90.0058646)
# 27     HOMICIDE BY SHOOTING  (29.97946128, -90.06256029)
# 28  SIMPLE BURGLARY VEHICLE  (30.00622969, -90.08288183)
# 29       RESIDENCE BURGLARY  (29.94190101, -90.02257831)

# %%
dfCrime.dtypes
# Out:
# TypeText    object
# Location    object
# dtype: object

# %%
# Extract lat and lon using regex (handles parentheses and commas)
dfCrime[['lat', 'lon']] = dfCrime['Location'].str.extract(r'\(([^,]+),\s*([^)]+)\)').astype(float)

# Create Point geometry
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['lon'], row['lat']), axis=1)

dfCrime = dfCrime[['TypeText', 'Location', 'geometry']]

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("/Users/austincoffelt/Documents/Rent-Walk-Local/cb_2018_22_bg_500k/cb_2018_22_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (3463, 11)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      22      051  021801        1  1500000US220510218011  220510218011    1
# 1      22      051  027703        2  1500000US220510277032  220510277032    2
# 2      22      009  030100        1  1500000US220090301001  220090301001    1
# 3      22      001  961000        2  1500000US220019610002  220019610002    2
# 4      22      079  012100        1  1500000US220790121001  220790121001    1
#
#   LSAD      ALAND    AWATER                                           geometry
# 0   BG     759364         0  POLYGON ((-90.187 30.012, -90.182 30.012, -90....
# 1   BG     371159         0  POLYGON ((-90.118 29.848, -90.117 29.848, -90....
# 2   BG  562491448  34183405  POLYGON ((-92.053 31.162, -92.048 31.168, -92....
# 3   BG     590930         0  POLYGON ((-92.372 30.209, -92.371 30.209, -92....
# 4   BG    1179564         0  POLYGON ((-92.463 31.291, -92.463 31.292, -92....

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#                    TypeText                     Location  \
# 4   SIMPLE BURGLARY VEHICLE  (30.03414756, -89.92030106)
# 15                 HOMICIDE   (30.01148679, -90.0058646)
# 27     HOMICIDE BY SHOOTING  (29.97946128, -90.06256029)
# 28  SIMPLE BURGLARY VEHICLE  (30.00622969, -90.08288183)
# 29       RESIDENCE BURGLARY  (29.94190101, -90.02257831)
#
#                   geometry
# 4    POINT (-89.92 30.034)
# 15  POINT (-90.006 30.011)
# 27  POINT (-90.063 29.979)
# 28  POINT (-90.083 30.006)
# 29  POINT (-90.023 29.942)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (25973, 14)
#                    TypeText                     Location  \
# 4   SIMPLE BURGLARY VEHICLE  (30.03414756, -89.92030106)
# 15                 HOMICIDE   (30.01148679, -90.0058646)
# 27     HOMICIDE BY SHOOTING  (29.97946128, -90.06256029)
# 28  SIMPLE BURGLARY VEHICLE  (30.00622969, -90.08288183)
# 29       RESIDENCE BURGLARY  (29.94190101, -90.02257831)
#
#                   geometry  index_right STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 4    POINT (-89.92 30.034)        872.0      22      071  001750        3
# 15  POINT (-90.006 30.011)       2041.0      22      071  001751        1
# 27  POINT (-90.063 29.979)         83.0      22      071  003000        2
# 28  POINT (-90.083 30.006)        108.0      22      071  003302        3
# 29  POINT (-90.023 29.942)        470.0      22      071  000605        2
#
#                  AFFGEOID         GEOID NAME LSAD       ALAND     AWATER
# 4   1500000US220710017503  220710017503    3   BG    530627.0    29041.0
# 15  1500000US220710017511  220710017511    1   BG  42147730.0  4778214.0
# 27  1500000US220710030002  220710030002    2   BG    190414.0        0.0
# 28  1500000US220710033023  220710033023    3   BG    460370.0    49360.0
# 29  1500000US220710006052  220710006052    2   BG    318564.0   244035.0

# %%
crime = result['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US220710134003    1164
# 1500000US220710135001     563
# 1500000US220710134001     464
# 1500000US220710134002     456
# 1500000US220710017511     361
#                          ...
# 1500000US220710017024       3
# 1500000US220510258002       2
# 1500000US220710016001       2
# 1500000US220510249002       1
# 1500000US220710011003       1
# Name: count, Length: 498, dtype: int64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_All_Crime_BG.csv')

# %%
result2 = result[result['TypeText'].isin(violentCrimes)]
crime = result2['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US220710134003    65
# 1500000US220710017511    45
# 1500000US220710134002    42
# 1500000US220710017204    35
# 1500000US220710135003    28
#                          ..
# 1500000US220710014023     1
# 1500000US220710121021     1
# 1500000US220710017021     1
# 1500000US220710065002     1
# 1500000US220710025011     1
# Name: count, Length: 392, dtype: int64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_Violent_Crime_BG.csv')

# %%
result3 = result[result['TypeText'].isin(propertyCrimes)]
crime = result3['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US220710134003    1099
# 1500000US220710135001     536
# 1500000US220710134001     448
# 1500000US220710134002     414
# 1500000US220710017511     316
#                          ...
# 1500000US220710070001       4
# 1500000US220710017024       3
# 1500000US220510258002       2
# 1500000US220710016001       2
# 1500000US220710011003       1
# Name: count, Length: 496, dtype: int64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_Property_Crime_BG.csv')

# %%
result4 = result[result['TypeText'].isin(['AUTO THEFT'])]
crime = result4['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US220710134003    119
# 1500000US220710134001     86
# 1500000US220710134002     79
# 1500000US220710135001     70
# 1500000US220710017511     70
#                         ...
# 1500000US220710069001      1
# 1500000US220710017024      1
# 1500000US220710116001      1
# 1500000US220710014011      1
# 1500000US220710116002      1
# Name: count, Length: 484, dtype: int64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_MV_Crime_BG.csv')
