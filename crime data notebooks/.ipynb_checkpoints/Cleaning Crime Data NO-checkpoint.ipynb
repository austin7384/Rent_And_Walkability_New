# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
from shapely.wkt import loads

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Calls_for_Service_2018_20250419.csv')
temp = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Calls_for_Service_2019_20250428.csv')
tem2 = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Calls_for_Service_2017_20250430.csv')
dfCrime = pd.concat([dfCrime, temp, tem2])
print(dfCrime.shape)
dfCrime.head()
# Out:
# (1392347, 23)
#   NOPD_Item Type_             TypeText Priority InitialType  \
# 0  A1964518   67C  THEFT FROM EXTERIOR       1A         62C
# 1  A1213518    21      COMPLAINT OTHER       1J          21
# 2  A0838218    37   AGGRAVATED ASSAULT       1C         103
# 3  B0948918   21P        LOST PROPERTY       0G         21P
# 4  A0609918    24              MEDICAL       2B          29
#
#            InitialTypeText InitialPriority      MapX     MapY  \
# 0  SIMPLE BURGLARY VEHICLE              1G         0        0
# 1          COMPLAINT OTHER              1J         0        0
# 2      DISTURBANCE (OTHER)              2A         0        0
# 3            LOST PROPERTY              0G  37369000  3513814
# 4                    DEATH              1B  37369000  3513814
#
#                TimeCreate  ... Disposition         DispositionText  \
# 0  01/17/2018 04:10:29 PM  ...         GOA         GONE ON ARRIVAL
# 1  01/11/2018 12:35:07 AM  ...         NAT  Necessary Action Taken
# 2  01/08/2018 01:24:10 AM  ...         RTF        REPORT TO FOLLOW
# 3  02/09/2018 01:18:23 AM  ...         RTF        REPORT TO FOLLOW
# 4  01/06/2018 01:15:19 AM  ...         NAT  Necessary Action Taken
#
#   SelfInitiated  Beat              BLOCK_ADDRESS      Zip PoliceDistrict  \
# 0             N  7L03     147XX Chef Menteur Hwy      NaN              0
# 1             Y  8D01  Bourbon St & Iberville St      NaN              0
# 2             N  8D06           007XX Bourbon St      NaN              0
# 3             N  8D05           004XX Bourbon St  70130.0              0
# 4             N  2L04              016XX Pine St  70118.0              2
#
#      Location  Type  TimeArrival
# 0         NaN   NaN          NaN
# 1         NaN   NaN          NaN
# 2         NaN   NaN          NaN
# 3  (0.0, 0.0)   NaN          NaN
# 4  (0.0, 0.0)   NaN          NaN
#
# [5 rows x 23 columns]

# %%
sorted(list(dfCrime['TypeText'].unique()))
# Out:
# ['ABANDONED BOAT',
#  'ABANDONED VEHICLE',
#  'AGGRAVATED ARSON',
#  'AGGRAVATED ASSAULT',
#  'AGGRAVATED ASSAULT DOMESTIC',
#  'AGGRAVATED BATTERY',
#  'AGGRAVATED BATTERY BY CUTTING',
#  'AGGRAVATED BATTERY BY KNIFE',
#  'AGGRAVATED BATTERY BY SHOOTING',
#  'AGGRAVATED BATTERY DOMESTIC',
#  'AGGRAVATED BURGLARY',
#  'AGGRAVATED BURGLARY DOMESTIC',
#  'AGGRAVATED CRIMINAL DAMAGE',
#  'AGGRAVATED ESCAPE',
#  'AGGRAVATED KIDNAPPING',
#  'AGGRAVATED RAPE',
#  'AGGRAVATED RAPE MALE VICTIM',
#  'AGGRAVATED RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE',
#  'AIRPLANE CRASH',
#  'AREA CHECK',
#  'ARMED ROBBERY',
#  'ARMED ROBBERY WITH GUN',
#  'ARMED ROBBERY WITH KNIFE',
#  'ASSET SEIZURE',
#  'ATTACHMENT',
#  'AUTO ACCIDENT',
#  'AUTO ACCIDENT CITY VEHICLE',
#  'AUTO ACCIDENT FATALITY',
#  'AUTO ACCIDENT POLICE VEHICLE',
#  'AUTO ACCIDENT WITH INJURY',
#  'AUTO THEFT',
#  'BICYCLE THEFT',
#  'BLIGHTED PROPERTY',
#  'BOMB SCARE',
#  'BURGLAR ALARM, LOCAL',
#  'BURGLAR ALARM, SILENT',
#  'BURGLAR ALARM, SILENT, FAR NO RESPONSE',
#  'BUSINESS BURGLARY',
#  'BUSINESS CHECK',
#  'CAD TEST',
#  'CARJACKING',
#  'CARJACKING- NO WEAPON',
#  'COMPLAINT OTHER',
#  'CONTRIBUTING TO DELINQUENCY',
#  'CRIME AGAINST NATURE',
#  'CRIMINAL DAMAGE DOMESTIC',
#  'CRIMINAL MISCHIEF',
#  'CRIMINAL MISCHIEF DOMESTIC',
#  'CRUELTY TO ANIMALS',
#  'CURFEW VIOLATION',
#  'DAILY WALKING BEAT LOG',
#  'DEATH',
#  'DESECRATION OF GRAVES',
#  'DIRECTED PATROL',
#  'DIRECTED TRAFFIC ENFORCEMENT',
#  'DISCHARGING FIREARM',
#  'DISPERSE SUBJECTS',
#  'DISTURBANCE (OTHER)',
#  'DOMESTIC DISTURBANCE',
#  'DRIVING WHILE UNDER INFLUENCE',
#  'DRUG VIOLATIONS',
#  'DRUNK',
#  'ELECTRONIC MONITORING',
#  'EXPLOSION',
#  'EXTORTION (THREATS)',
#  'EXTORTION (THREATS) DOMESTIC',
#  'FIGHT',
#  'FIRE',
#  'FIRE/RESCUE',
#  'FIREBOMB',
#  'FIREWORKS',
#  'FLOOD EVENT',
#  'FLOODED VEHICLE',
#  'FORGERY',
#  'FUGITIVE ATTACHMENT',
#  'GAMBLING',
#  'HIT & RUN',
#  'HIT & RUN CITY VEHICLE',
#  'HIT & RUN FATALITY',
#  'HIT & RUN POLICE VEHICLE',
#  'HIT & RUN WITH INJURIES',
#  'HOLD UP ALARM',
#  'HOMELESS',
#  'HOMICIDE',
#  'HOMICIDE BY CUTTING',
#  'HOMICIDE BY SHOOTING',
#  'HOMICIDE DOMESTIC',
#  'HOSTAGE SITUATION',
#  'ILLEGAL CARRYING OF WEAPON',
#  'ILLEGAL CARRYING OF WEAPON- GUN',
#  'ILLEGAL CARRYING OF WEAPON- KNIFE',
#  'IMPERSONATING AN OFFICER',
#  'INCIDENT REQUESTED BY ANOTHER AGENCY',
#  'INDECENT BEHAVIOR',
#  'ISSUING WORTHLESS CHECKS',
#  'JUVENILE ATTACHMENT',
#  'LOST PROPERTY',
#  'MEDICAL',
#  'MEDICAL - NALOXONE',
#  'MEDICAL SEXUAL ASSAULT KIT PROCESSING',
#  'MEET AN OFFICER',
#  'MENTAL PATIENT',
#  'MISDEMEANOR SEXUAL BATTERY',
#  'MISSING ADULT',
#  'MISSING JUVENILE',
#  'MUNICIPAL ATTACHMENT',
#  'NEGLIENT INJURY',
#  'NOISE COMPLAINT',
#  'OBSCENITY, EXPOSING',
#  'OFFICER NEEDS ASSISTANCE',
#  'OFFICER NEEDS ASSISTANCE, LIFE IN DANGER',
#  'ORAL SEXUAL BATTERY',
#  'PANDERING',
#  'PARADE ITEM NUMBER',
#  'PEEPING TOM',
#  'PICKPOCKET',
#  'POLICE VEHICLE ACCIDENT',
#  'POSSESSION OF STOLEN PROPERTY',
#  'PROSTITUTION',
#  'PROTEST',
#  'PROWLER',
#  'PUBLIC GATHERING',
#  'QUALITY OF LIFE ISSUE',
#  'RECKLESS DRIVING',
#  'RECOVERY OF REPORTED STOLEN VEHICLE',
#  'RECOVERY OF VEHICLE',
#  'RESIDENCE BURGLARY',
#  'RESIDENCE CHECK',
#  'RETURN FOR ADDITIONAL INFO',
#  'RIOT',
#  'SAFE BURGLARY',
#  'SEX OFFENDER REGISTRATION CHECK',
#  'SEXTING',
#  'SEXUAL BATTERY',
#  'SHOPLIFTING',
#  'SILENT 911 CALL',
#  'SIMPLE ARSON',
#  'SIMPLE ARSON DOMESTIC',
#  'SIMPLE ASSAULT',
#  'SIMPLE ASSAULT DOMESTIC',
#  'SIMPLE BATTERY',
#  'SIMPLE BATTERY DOMESTIC',
#  'SIMPLE BURGLARY',
#  'SIMPLE BURGLARY DOMESTIC',
#  'SIMPLE BURGLARY VEHICLE',
#  'SIMPLE CRIMINAL DAMAGE',
#  'SIMPLE ESCAPE',
#  'SIMPLE KIDNAPPING',
#  'SIMPLE RAPE',
#  'SIMPLE RAPE MALE VICTIM',
#  'SIMPLE RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE',
#  'SIMPLE ROBBERY',
#  'SIMPLE ROBBERY, PROPERTY SNATCHING',
#  'SIMULTANEOS STOLEN/RECOVERY VEHICLE',
#  'SOLICITING FOR PROSTITUTION',
#  'SUICIDE',
#  'SUICIDE ATTEMPT',
#  'SUICIDE THREAT',
#  'SUSPICIOUS PACKAGE',
#  'SUSPICIOUS PERSON',
#  'TAKING TEMPORARY POSSESSION',
#  'THEFT',
#  'THEFT BY EMBEZZLEMENT',
#  'THEFT BY FRAUD',
#  'THEFT FROM EXTERIOR',
#  'THEFT FROM EXTERIOR OF VEHICLE',
#  'TOW IMPOUNDED VEHICLE (PRIVATE)',
#  'TRAFFIC ATTACHMENT',
#  'TRAFFIC CONGESTION',
#  'TRAFFIC INCIDENT',
#  'TRAFFIC STOP',
#  'TROOP N AREA - BUSINESS - RESIDENCE CHECK',
#  'TRUANT VIOLATION',
#  'UNATTENDED PACKAGE',
#  'UNAUTHORIZED USE OF VEHICLE',
#  'UNCLASSIFIED DEATH',
#  'UNDERAGE DRINKING VIOLATION',
#  'UNDERPASS MONITORING OR CLOSURE',
#  'UNLAWFUL SALES TO MINORS',
#  'VEHICLE NO-PURSUIT',
#  'VEHICLE PURSUIT',
#  'VIDEO VOYEURISM',
#  'VIOLATION OF PROTECTION ORDER',
#  'WALKING BEAT',
#  'WARR STOP WITH RELEASE']

# %%
violentCrimes = ['AGGRAVATED ASSAULT', 'AGGRAVATED ASSAULT DOMESTIC', 'AGGRAVATED RAPE', 'AGGRAVATED RAPE MALE VICTIM', 
                 'AGGRAVATED RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE', 'ARMED ROBBERY', 'ARMED ROBBERY WITH GUN', 
                 'ARMED ROBBERY WITH KNIFE', 'HOMICIDE', 'HOMICIDE BY CUTTING', 'HOMICIDE BY SHOOTING', 'HOMICIDE DOMESTIC',
                'SIMPLE RAPE', 'SIMPLE RAPE MALE VICTIM', 'SIMPLE RAPE UNFOUNDED BY SPECIAL VICTIMS OR CHILD ABUSE']
propertyCrimes = ['BUSINESS BURGLARY', 'CARJACKING', 'CARJACKING- NO WEAPON',  'RESIDENCE BURGLARY', 'SAFE BURGLARY', 'SIMPLE BURGLARY',
                  'SIMPLE BURGLARY DOMESTIC', 'SIMPLE BURGLARY VEHICLE', 'THEFT', 'THEFT FROM EXTERIOR OF VEHICLE', 'AGGRAVATED BURGLARY',
                  'AGGRAVATED BURGLARY DOMESTIC', 'AUTO THEFT', 'BICYCLE THEFT']
both = violentCrimes + propertyCrimes
dfCrime = dfCrime[dfCrime['TypeText'].isin(both)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (69309, 23)
#     NOPD_Item Type_            TypeText Priority InitialType  \
# 2    A0838218    37  AGGRAVATED ASSAULT       1C         103
# 70   B1357518    37  AGGRAVATED ASSAULT       1E          37
# 126  A1607318    37  AGGRAVATED ASSAULT       1A          37
# 155  A1620818    67               THEFT       0A          67
# 200  A0367218   62R  RESIDENCE BURGLARY       2A          62
#
#          InitialTypeText InitialPriority     MapX    MapY  \
# 2    DISTURBANCE (OTHER)              2A        0       0
# 70    AGGRAVATED ASSAULT              1E  3694198  559742
# 126   AGGRAVATED ASSAULT              1E  3670226  535972
# 155                THEFT              1G  3681879  531499
# 200      SIMPLE BURGLARY              2A  3705177  512629
#
#                  TimeCreate  ... Disposition   DispositionText SelfInitiated  \
# 2    01/08/2018 01:24:10 AM  ...         RTF  REPORT TO FOLLOW             N
# 70   02/11/2018 11:54:41 PM  ...         RTF  REPORT TO FOLLOW             N
# 126  01/14/2018 08:49:04 AM  ...         UNF         UNFOUNDED             N
# 155  01/14/2018 12:21:05 PM  ...         GOA   GONE ON ARRIVAL             N
# 200  01/03/2018 11:36:51 PM  ...         RTF  REPORT TO FOLLOW             N
#
#      Beat            BLOCK_ADDRESS      Zip PoliceDistrict  \
# 2    8D06         007XX Bourbon St      NaN              0
# 70   7A05  Downman Rd & Hayne Blvd  70126.0              3
# 126  1L04         039XX Tulane Ave  70119.0              1
# 155  8C02           003XX Royal St  70130.0              8
# 200  4D05          057XX Tullis Dr  70131.0              4
#
#                         Location  Type  TimeArrival
# 2                            NaN   NaN          NaN
# 70    (30.03270567, -90.0269583)   NaN          NaN
# 126  (29.96807474, -90.10351781)   NaN          NaN
# 155  (29.95542795, -90.06687159)   NaN          NaN
# 200  (29.90281221, -89.99400291)   NaN          NaN
#
# [5 rows x 23 columns]

# %%
dfCrime = dfCrime[['TypeText', 'Location']]
dfCrime = dfCrime[dfCrime['Location'] != '(0.0, 0.0)']
dfCrime = dfCrime[dfCrime['Location'].isna() == False]
dfCrime.head()
# Out:
#                    TypeText                     Location
# 70       AGGRAVATED ASSAULT   (30.03270567, -90.0269583)
# 126      AGGRAVATED ASSAULT  (29.96807474, -90.10351781)
# 155                   THEFT  (29.95542795, -90.06687159)
# 200      RESIDENCE BURGLARY  (29.90281221, -89.99400291)
# 219  ARMED ROBBERY WITH GUN  (29.94109943, -90.07916897)

# %%
dfCrime.dtypes
# Out:
# TypeText    object
# Location    object
# dtype: object

# %%
# Extract lat and lon using regex (handles parentheses and commas)
dfCrime[['lat', 'lon']] = dfCrime['Location'].str.extract(r'\(([^,]+),\s*([^)]+)\)').astype(float)

# Create Point geometry
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['lon'], row['lat']), axis=1)

dfCrime = dfCrime[['TypeText', 'Location', 'geometry']]

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("/Users/austincoffelt/Documents/Rent-Walk-Local/cb_2018_22_bg_500k/cb_2018_22_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (3463, 11)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      22      051  021801        1  1500000US220510218011  220510218011    1
# 1      22      051  027703        2  1500000US220510277032  220510277032    2
# 2      22      009  030100        1  1500000US220090301001  220090301001    1
# 3      22      001  961000        2  1500000US220019610002  220019610002    2
# 4      22      079  012100        1  1500000US220790121001  220790121001    1
#
#   LSAD      ALAND    AWATER                                           geometry
# 0   BG     759364         0  POLYGON ((-90.187 30.012, -90.182 30.012, -90....
# 1   BG     371159         0  POLYGON ((-90.118 29.848, -90.117 29.848, -90....
# 2   BG  562491448  34183405  POLYGON ((-92.053 31.162, -92.048 31.168, -92....
# 3   BG     590930         0  POLYGON ((-92.372 30.209, -92.371 30.209, -92....
# 4   BG    1179564         0  POLYGON ((-92.463 31.291, -92.463 31.292, -92....

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#                    TypeText                     Location  \
# 70       AGGRAVATED ASSAULT   (30.03270567, -90.0269583)
# 126      AGGRAVATED ASSAULT  (29.96807474, -90.10351781)
# 155                   THEFT  (29.95542795, -90.06687159)
# 200      RESIDENCE BURGLARY  (29.90281221, -89.99400291)
# 219  ARMED ROBBERY WITH GUN  (29.94109943, -90.07916897)
#
#                    geometry
# 70   POINT (-90.027 30.033)
# 126  POINT (-90.104 29.968)
# 155  POINT (-90.067 29.955)
# 200  POINT (-89.994 29.903)
# 219  POINT (-90.079 29.941)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (67148, 14)
#                    TypeText                     Location  \
# 70       AGGRAVATED ASSAULT   (30.03270567, -90.0269583)
# 126      AGGRAVATED ASSAULT  (29.96807474, -90.10351781)
# 155                   THEFT  (29.95542795, -90.06687159)
# 200      RESIDENCE BURGLARY  (29.90281221, -89.99400291)
# 219  ARMED ROBBERY WITH GUN  (29.94109943, -90.07916897)
#
#                    geometry  index_right STATEFP COUNTYFP TRACTCE BLKGRPCE  \
# 70   POINT (-90.027 30.033)       2516.0      22      071  001720        4
# 126  POINT (-90.104 29.968)       2008.0      22      071  007101        2
# 155  POINT (-90.067 29.955)        780.0      22      071  013500        1
# 200  POINT (-89.994 29.903)       2040.0      22      071  000617        2
# 219  POINT (-90.079 29.941)        913.0      22      071  013900        2
#
#                   AFFGEOID         GEOID NAME LSAD      ALAND    AWATER
# 70   1500000US220710017204  220710017204    4   BG  1986504.0  233905.0
# 126  1500000US220710071012  220710071012    2   BG   535661.0       0.0
# 155  1500000US220710135001  220710135001    1   BG   369821.0  186999.0
# 200  1500000US220710006172  220710006172    2   BG   447795.0  137853.0
# 219  1500000US220710139002  220710139002    2   BG   255692.0       0.0

# %%
crime = result['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US220710134003    981.666667
# 1500000US220710135001    491.666667
# 1500000US220710134002    416.333333
# 1500000US220710134001    390.000000
# 1500000US220710017511    307.333333
#                             ...
# 1500000US220510258002      2.333333
# 1500000US220510249002      1.333333
# 1500000US220710011003      1.000000
# 1500000US220510250021      0.333333
# 1500000US220870302045      0.333333
# Name: count, Length: 500, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_All_Crime_BG.csv')

# %%
result2 = result[result['TypeText'].isin(violentCrimes)]
crime = result2['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US220710134003    60.666667
# 1500000US220710017511    42.333333
# 1500000US220710017204    31.666667
# 1500000US220710135001    31.000000
# 1500000US220710134002    27.333333
#                            ...
# 1500000US220710126001     0.333333
# 1500000US220710091002     0.333333
# 1500000US220710116001     0.333333
# 1500000US220710096002     0.333333
# 1500000US220710076063     0.333333
# Name: count, Length: 475, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_Violent_Crime_BG.csv')

# %%
result3 = result[result['TypeText'].isin(propertyCrimes)]
crime = result3['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US220710134003    921.000000
# 1500000US220710135001    460.666667
# 1500000US220710134002    389.000000
# 1500000US220710134001    376.333333
# 1500000US220710135003    281.333333
#                             ...
# 1500000US220710007011      5.000000
# 1500000US220710070001      5.000000
# 1500000US220510258002      2.333333
# 1500000US220710011003      0.666667
# 1500000US220510249002      0.666667
# Name: count, Length: 498, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_Property_Crime_BG.csv')

# %%
result4 = result[result['TypeText'].isin(['AUTO THEFT'])]
crime = result4['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US220710134003    102.000000
# 1500000US220710134002     64.333333
# 1500000US220710017511     63.333333
# 1500000US220710134001     58.333333
# 1500000US220710135001     56.000000
#                             ...
# 1500000US220710056013      1.000000
# 1500000US220710070001      1.000000
# 1500000US220710121022      0.666667
# 1500000US220710076041      0.666667
# 1500000US220510249002      0.333333
# Name: count, Length: 496, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/NO_MV_Crime_BG.csv')
