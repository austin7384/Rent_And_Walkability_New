# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Police_Department_Incident_Reports__2018_to_Present_20250412.csv')
temp = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Police_Department_Incident_Reports__Historical_2003_to_May_2018_20250430.csv')
dfCrime = pd.concat([dfCrime, temp])
print(dfCrime.shape)
dfCrime.head()
# Out:
# (3077435, 68)
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/01 05:02:00 AM    2023/03/01         05:02         2023.0
# 1  2023/03/13 10:59:00 AM    2023/03/13         10:59         2023.0
# 2  2023/03/14 06:44:00 PM    2023/03/14         18:44         2023.0
# 3  2023/02/15 03:00:00 AM    2023/02/15         03:00         2023.0
# 4  2023/03/11 03:00:00 PM    2023/03/11         15:00         2023.0
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0            Wednesday  2023/03/11 03:40:00 PM  1.253795e+11    1253795.0
# 1               Monday  2023/03/13 11:00:00 AM  1.253551e+11    1253551.0
# 2              Tuesday  2023/03/14 06:45:00 PM  1.254024e+11    1254024.0
# 3            Wednesday  2023/03/11 04:55:00 PM  1.253786e+11    1253786.0
# 4             Saturday  2023/03/13 08:29:00 AM  1.254206e+11    1254206.0
#
#    Incident Number  CAD Number  ... Fix It Zones as of 2017-11-06  2 2  \
# 0      236046151.0         NaN  ...                                NaN
# 1      230174885.0         NaN  ...                                NaN
# 2      230176728.0         NaN  ...                                NaN
# 3      236046123.0         NaN  ...                                NaN
# 4      236045937.0         NaN  ...                                NaN
#
#   DELETE - HSOC Zones 2 2 Fix It Zones as of 2018-02-07 2 2  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                               NaN
#
#    CBD, BID and GBD Boundaries as of 2017 2 2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Areas of Vulnerability, 2016 2 2 Central Market/Tenderloin Boundary 2 2  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
#
#   Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   HSOC Zones as of 2018-06-05 2 2 OWED Public Spaces 2 2  Neighborhoods 2
# 0                             NaN                    NaN              NaN
# 1                             NaN                    NaN              NaN
# 2                             NaN                    NaN              NaN
# 3                             NaN                    NaN              NaN
# 4                             NaN                    NaN              NaN
#
# [5 rows x 68 columns]

# %%
dfCrime = dfCrime[(dfCrime['Latitude'].isna() == False) & (dfCrime['Longitude'].isna() == False)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (896213, 68)
#           Incident Datetime Incident Date Incident Time  Incident Year  \
# 6    2022/06/27 12:00:00 PM    2022/06/27         12:00         2022.0
# 8    2023/03/16 05:30:00 PM    2023/03/16         17:30         2023.0
# 26   2023/03/21 03:50:00 PM    2023/03/21         15:50         2023.0
# 144  2021/07/03 12:00:00 PM    2021/07/03         12:00         2021.0
# 145  2021/07/22 07:16:00 PM    2021/07/22         19:16         2021.0
#
#     Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 6                 Monday  2023/03/15 05:20:00 PM  1.254394e+11    1254393.0
# 8               Thursday  2023/03/16 06:02:00 PM  1.254826e+11    1254826.0
# 26               Tuesday  2023/03/21 04:01:00 PM  1.256564e+11    1256563.0
# 144             Saturday  2021/07/03 12:37:00 PM  1.046245e+11    1046244.0
# 145             Thursday  2021/07/23 01:35:00 PM  1.053416e+11    1053415.0
#
#      Incident Number   CAD Number  ... Fix It Zones as of 2017-11-06  2 2  \
# 6        230184129.0  230742480.0  ...                                NaN
# 8        230187101.0  230752550.0  ...                                NaN
# 26       230199764.0  230802198.0  ...                                NaN
# 144      210417332.0  211841413.0  ...                                NaN
# 145      216098495.0          NaN  ...                                NaN
#
#     DELETE - HSOC Zones 2 2 Fix It Zones as of 2018-02-07 2 2  \
# 6                       NaN                               NaN
# 8                       NaN                               NaN
# 26                      NaN                               NaN
# 144                     NaN                               NaN
# 145                     NaN                               NaN
#
#      CBD, BID and GBD Boundaries as of 2017 2 2  \
# 6                                           NaN
# 8                                           NaN
# 26                                          NaN
# 144                                         NaN
# 145                                         NaN
#
#     Areas of Vulnerability, 2016 2 2 Central Market/Tenderloin Boundary 2 2  \
# 6                                NaN                                    NaN
# 8                                NaN                                    NaN
# 26                               NaN                                    NaN
# 144                              NaN                                    NaN
# 145                              NaN                                    NaN
#
#     Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 6                                                  NaN
# 8                                                  NaN
# 26                                                 NaN
# 144                                                NaN
# 145                                                NaN
#
#     HSOC Zones as of 2018-06-05 2 2 OWED Public Spaces 2 2  Neighborhoods 2
# 6                               NaN                    NaN              NaN
# 8                               NaN                    NaN              NaN
# 26                              NaN                    NaN              NaN
# 144                             NaN                    NaN              NaN
# 145                             NaN                    NaN              NaN
#
# [5 rows x 68 columns]

# %%
dfCrime = dfCrime[dfCrime['Incident Year'].isin([2019, 2018, 2017])]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (282061, 68)
#            Incident Datetime Incident Date Incident Time  Incident Year  \
# 200   2019/06/11 04:30:00 PM    2019/06/11         16:30         2019.0
# 790   2019/06/01 12:00:00 AM    2019/06/01         00:00         2019.0
# 1533  2018/12/01 12:00:00 PM    2018/12/01         12:00         2018.0
# 1990  2018/11/10 03:00:00 PM    2018/11/10         15:00         2018.0
# 3021  2018/03/07 07:00:00 AM    2018/03/07         07:00         2018.0
#
#      Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 200               Tuesday  2021/06/05 05:17:00 AM  1.037700e+11    1037700.0
# 790              Saturday  2022/03/29 10:45:00 AM  1.135367e+11    1135366.0
# 1533             Saturday  2025/03/19 04:20:00 PM  1.469998e+11    1469998.0
# 1990             Saturday  2025/03/26 03:16:00 PM  1.471689e+11    1471688.0
# 3021            Wednesday  2023/08/24 05:33:00 AM  1.312400e+11    1312400.0
#
#       Incident Number   CAD Number  ... Fix It Zones as of 2017-11-06  2 2  \
# 200       210348157.0  211560467.0  ...                                NaN
# 790       220204947.0  220881074.0  ...                                NaN
# 1533      180951860.0          NaN  ...                                NaN
# 1990      250170885.0  250852094.0  ...                                NaN
# 3021      190202001.0          NaN  ...                                NaN
#
#      DELETE - HSOC Zones 2 2 Fix It Zones as of 2018-02-07 2 2  \
# 200                      NaN                               NaN
# 790                      NaN                               NaN
# 1533                     NaN                               NaN
# 1990                     NaN                               NaN
# 3021                     NaN                               NaN
#
#       CBD, BID and GBD Boundaries as of 2017 2 2  \
# 200                                          NaN
# 790                                          NaN
# 1533                                         NaN
# 1990                                         NaN
# 3021                                         NaN
#
#      Areas of Vulnerability, 2016 2 2 Central Market/Tenderloin Boundary 2 2  \
# 200                               NaN                                    NaN
# 790                               NaN                                    NaN
# 1533                              NaN                                    NaN
# 1990                              NaN                                    NaN
# 3021                              NaN                                    NaN
#
#      Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 200                                                 NaN
# 790                                                 NaN
# 1533                                                NaN
# 1990                                                NaN
# 3021                                                NaN
#
#      HSOC Zones as of 2018-06-05 2 2 OWED Public Spaces 2 2  Neighborhoods 2
# 200                              NaN                    NaN              NaN
# 790                              NaN                    NaN              NaN
# 1533                             NaN                    NaN              NaN
# 1990                             NaN                    NaN              NaN
# 3021                             NaN                    NaN              NaN
#
# [5 rows x 68 columns]

# %%
list(dfCrime['Incident Subcategory'].unique())
# Out:
# ['Rape',
#  'Courtesy Report',
#  'Fraud',
#  'Miscellaneous Investigation',
#  'Larceny Theft - Other',
#  'Lost Property',
#  'Motor Vehicle Theft',
#  'Missing Adult',
#  'Simple Assault',
#  'Case Closure',
#  'Non-Criminal',
#  'Suspicious Occ',
#  'Other',
#  'Larceny - From Vehicle',
#  'Larceny Theft - Shoplifting',
#  'Embezzlement',
#  'Forgery And Counterfeiting',
#  'Stolen Property',
#  'Robbery - Other',
#  'Larceny Theft - From Building',
#  'Aggravated Assault',
#  'Sex Offense',
#  'Vandalism',
#  'Robbery - Street',
#  'Recovered Vehicle',
#  'Arson',
#  'Trespass',
#  'Theft From Vehicle',
#  'Drug Violation',
#  nan,
#  'Missing Person',
#  'Prostitution',
#  'Disorderly Conduct',
#  'Robbery - Commercial',
#  'Intimidation',
#  'Suicide',
#  'Larceny Theft - Bicycle',
#  'Fire Report',
#  'Burglary - Commercial',
#  'Vehicle Impounded',
#  'Weapons Offense',
#  'Stalking',
#  'Burglary - Residential',
#  'Traffic Violation Arrest',
#  'Warrant',
#  'Manslaughter',
#  'Burglary - Other',
#  'Drunkenness',
#  'Kidnapping',
#  'Other Offenses',
#  'Larceny Theft - Pickpocket',
#  'Traffic Collision - Hit & Run',
#  'Burglary - Hot Prowl',
#  'Robbery - Carjacking',
#  'Loitering',
#  'Motor Vehicle Theft (Attempted)',
#  'Larceny Theft - Purse Snatch',
#  'Larceny - Auto Parts',
#  'Extortion-Blackmail',
#  'Human Trafficking, Commercial Sex Acts',
#  'Liquor Law Violation',
#  'Traffic Collision',
#  'Vehicle Misplaced',
#  'Suspicious Package',
#  'Gambling',
#  'Rape - Attempted',
#  'Bad Checks',
#  'Robbery - Residential',
#  'Bribery',
#  'Homicide',
#  'Arrest',
#  'Human Trafficking, Involuntary Servitude']

# %%
violentCrimes = ['Aggravated Assault', 'Rape - Attempted', 'Robbery - Residential', 'Robbery - Street', 'Robbery - Carjacking',
                'Sex Offense', 'Robbery - Commercial', 'Rape', 'Homicide', 'Robbery - Other']
propertyCrimes = ['Motor Vehicle Theft', 'Larceny Theft - Other', 'Larceny - From Vehicle', 'Larceny Theft - Shoplifting',
                  'Larceny Theft - From Building', 'Theft From Vehicle', 'Burglary - Commercial', 'Burglary - Residential',
                  'Burglary - Other', 'Larceny Theft - Pickpocket', 'Burglary - Hot Prowl', 'Larceny Theft - Bicycle', 
                  'Larceny - Auto Parts', 'Larceny Theft - Purse Snatch', 'Motor Vehicle Theft (Attempted)']
both = violentCrimes + propertyCrimes
dfCrime = dfCrime[dfCrime['Incident Subcategory'].isin(both)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (125406, 68)
#            Incident Datetime Incident Date Incident Time  Incident Year  \
# 200   2019/06/11 04:30:00 PM    2019/06/11         16:30         2019.0
# 3021  2018/03/07 07:00:00 AM    2018/03/07         07:00         2018.0
# 3071  2018/03/07 07:00:00 AM    2018/03/07         07:00         2018.0
# 6261  2019/07/26 08:00:00 AM    2019/07/26         08:00         2019.0
# 6428  2019/02/06 06:00:00 PM    2019/02/06         18:00         2019.0
#
#      Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 200               Tuesday  2021/06/05 05:17:00 AM  1.037700e+11    1037700.0
# 3021            Wednesday  2023/08/24 05:33:00 AM  1.312400e+11    1312400.0
# 3071            Wednesday  2023/08/24 06:37:00 PM  1.312401e+11    1312401.0
# 6261               Friday  2023/08/31 01:50:00 PM  1.313475e+11    1313475.0
# 6428            Wednesday  2023/02/10 03:32:00 PM  1.259824e+11    1259824.0
#
#       Incident Number   CAD Number  ... Fix It Zones as of 2017-11-06  2 2  \
# 200       210348157.0  211560467.0  ...                                NaN
# 3021      190202001.0          NaN  ...                                NaN
# 3071      190202001.0          NaN  ...                                NaN
# 6261      230622395.0  232430739.0  ...                                NaN
# 6428      236024323.0          NaN  ...                                NaN
#
#      DELETE - HSOC Zones 2 2 Fix It Zones as of 2018-02-07 2 2  \
# 200                      NaN                               NaN
# 3021                     NaN                               NaN
# 3071                     NaN                               NaN
# 6261                     NaN                               NaN
# 6428                     NaN                               NaN
#
#       CBD, BID and GBD Boundaries as of 2017 2 2  \
# 200                                          NaN
# 3021                                         NaN
# 3071                                         NaN
# 6261                                         NaN
# 6428                                         NaN
#
#      Areas of Vulnerability, 2016 2 2 Central Market/Tenderloin Boundary 2 2  \
# 200                               NaN                                    NaN
# 3021                              NaN                                    NaN
# 3071                              NaN                                    NaN
# 6261                              NaN                                    NaN
# 6428                              NaN                                    NaN
#
#      Central Market/Tenderloin Boundary Polygon - Updated 2 2  \
# 200                                                 NaN
# 3021                                                NaN
# 3071                                                NaN
# 6261                                                NaN
# 6428                                                NaN
#
#      HSOC Zones as of 2018-06-05 2 2 OWED Public Spaces 2 2  Neighborhoods 2
# 200                              NaN                    NaN              NaN
# 3021                             NaN                    NaN              NaN
# 3071                             NaN                    NaN              NaN
# 6261                             NaN                    NaN              NaN
# 6428                             NaN                    NaN              NaN
#
# [5 rows x 68 columns]

# %%
dfCrime = dfCrime[['Incident Subcategory', 'Longitude', 'Latitude']]
dfCrime.head()
# Out:
#        Incident Subcategory   Longitude   Latitude
# 200                    Rape -122.408846  37.775953
# 3021  Larceny Theft - Other -122.410731  37.768178
# 3071  Larceny Theft - Other -122.410731  37.768178
# 6261    Motor Vehicle Theft -122.404306  37.742521
# 6428  Larceny Theft - Other -122.416401  37.777723

# %%
# make our lon and lat into a point type for spacial join
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
dfCrime = dfCrime[['Incident Subcategory', 'geometry']]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (125406, 2)
#        Incident Subcategory                                      geometry
# 200                    Rape  POINT (-122.4088457506342 37.77595322850279)
# 3021  Larceny Theft - Other  POINT (-122.4107307185833 37.76817786907554)
# 3071  Larceny Theft - Other  POINT (-122.4107307185833 37.76817786907554)
# 6261    Motor Vehicle Theft    POINT (-122.40430629342 37.74252073319404)
# 6428  Larceny Theft - Other  POINT (-122.4164010718398 37.77772275002857)

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("/Users/austincoffelt/Documents/Rent-Walk-Local/cb_2018_06_bg_500k/cb_2018_06_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (23196, 11)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      06      075  980401        1  1500000US060759804011  060759804011    1
# 1      06      059  062702        1  1500000US060590627021  060590627021    1
# 2      06      037  576602        1  1500000US060375766021  060375766021    1
# 3      06      075  061500        6  1500000US060750615006  060750615006    6
# 4      06      049  000300        2  1500000US060490003002  060490003002    2
#
#   LSAD       ALAND     AWATER  \
# 0   BG      419323  247501289
# 1   BG      513205     635569
# 2   BG      246841    1907927
# 3   BG      313325     229501
# 4   BG  1781768492  310119189
#
#                                             geometry
# 0  POLYGON ((-123.01 37.7, -123.01 37.699, -123.0...
# 1  POLYGON ((-117.88 33.593, -117.88 33.595, -117...
# 2  MULTIPOLYGON (((-118.18 33.765, -118.17 33.765...
# 3  POLYGON ((-122.39 37.783, -122.39 37.787, -122...
# 4  POLYGON ((-120.82 41.994, -120.79 41.994, -120...

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#        Incident Subcategory                geometry
# 200                    Rape  POINT (-122.41 37.776)
# 3021  Larceny Theft - Other  POINT (-122.41 37.768)
# 3071  Larceny Theft - Other  POINT (-122.41 37.768)
# 6261    Motor Vehicle Theft   POINT (-122.4 37.743)
# 6428  Larceny Theft - Other  POINT (-122.42 37.778)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (125406, 13)
#        Incident Subcategory                geometry  index_right STATEFP  \
# 200                    Rape  POINT (-122.41 37.776)      11436.0      06
# 3021  Larceny Theft - Other  POINT (-122.41 37.768)      20625.0      06
# 3071  Larceny Theft - Other  POINT (-122.41 37.768)      20625.0      06
# 6261    Motor Vehicle Theft   POINT (-122.4 37.743)      15447.0      06
# 6428  Larceny Theft - Other  POINT (-122.42 37.778)      19117.0      06
#
#      COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME LSAD  \
# 200       075  017802        1  1500000US060750178021  060750178021    1   BG
# 3021      075  017700        1  1500000US060750177001  060750177001    1   BG
# 3071      075  017700        1  1500000US060750177001  060750177001    1   BG
# 6261      075  980900        1  1500000US060759809001  060759809001    1   BG
# 6428      075  012402        2  1500000US060750124022  060750124022    2   BG
#
#           ALAND    AWATER
# 200    320288.0       0.0
# 3021   451236.0       0.0
# 3071   451236.0       0.0
# 6261  3585240.0  260707.0
# 6428   196307.0       0.0

# %%
crime = result['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US060750117002    1592.666667
# 1500000US060750615001    1125.333333
# 1500000US060750101001     954.333333
# 1500000US060750102001     675.000000
# 1500000US060750105002     583.000000
#                             ...
# 1500000US060750352011       3.000000
# 1500000US060816009001       2.333333
# 1500000US060816004012       2.000000
# 1500000US060816007001       1.000000
# 1500000US060750426021       0.333333
# Name: count, Length: 583, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/SF_All_Crime_BG.csv')

# %%
result2 = result[result['Incident Subcategory'].isin(violentCrimes)]
crime = result2['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US060750117002    151.333333
# 1500000US060750615001    138.000000
# 1500000US060750176015    116.000000
# 1500000US060750125012     94.333333
# 1500000US060750176013     86.333333
#                             ...
# 1500000US060750215004      0.333333
# 1500000US060750303022      0.333333
# 1500000US060750476003      0.333333
# 1500000US060750428001      0.333333
# 1500000US060750329013      0.333333
# Name: count, Length: 535, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/SF_Violent_Crime_BG.csv')

# %%
result3 = result[result['Incident Subcategory'].isin(propertyCrimes)]
crime = result3['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US060750117002    1441.333333
# 1500000US060750615001     987.333333
# 1500000US060750101001     918.333333
# 1500000US060750102001     656.333333
# 1500000US060759803001     547.333333
#                             ...
# 1500000US060816002001       3.000000
# 1500000US060816009001       2.000000
# 1500000US060816004012       2.000000
# 1500000US060816007001       1.000000
# 1500000US060750426021       0.333333
# Name: count, Length: 583, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/SF_Property_Crime_BG.csv')

# %%
result4 = result[result['Incident Subcategory'].isin(['Motor Vehicle Theft', 'Motor Vehicle Theft (Attempted)'])]
crime = result4['AFFGEOID'].value_counts() / 3
crime
# Out:
# AFFGEOID
# 1500000US060759809001    85.333333
# 1500000US060750180002    60.333333
# 1500000US060750177001    40.666667
# 1500000US060750615001    40.333333
# 1500000US060759803001    36.333333
#                            ...
# 1500000US060750477022     0.333333
# 1500000US060750113002     0.333333
# 1500000US060750128004     0.333333
# 1500000US060750327005     0.333333
# 1500000US060750426011     0.333333
# Name: count, Length: 578, dtype: float64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/SF_MV_Crime_BG.csv')
