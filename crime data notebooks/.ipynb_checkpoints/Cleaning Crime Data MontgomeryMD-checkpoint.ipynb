# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Crime.csv')
print(dfCrime.shape)
dfCrime.head()
# Out:
# (438822, 30)
# /var/folders/6z/0pv81j2524v8c80qsmnrbmcm0000gn/T/ipykernel_18905/1590329121.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Crime.csv')
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201166610         2308  170548599                     NaN
# 1    201359823         5404  220000965  01/09/2022 01:18:38 AM
# 2    201095140         2303   16043118                     NaN
# 3    201090710         5707   16037677                     NaN
# 4    201362142         2901  220003839  01/28/2022 07:11:29 PM
#
#           Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0  12/14/2017 04:30:00 PM                     NaN        23D        1
# 1  01/09/2022 01:34:00 AM                     NaN        90D        1
# 2  08/24/2016 09:47:00 PM                     NaN        23C        1
# 3  07/25/2016 05:31:00 PM                     NaN        90J        1
# 4  01/28/2022 02:40:00 PM  01/28/2022 02:46:00 PM        290        1
#
#               Crime Name1                               Crime Name2  ...  PRA  \
# 0  Crime Against Property                       Theft from Building  ...  270
# 1   Crime Against Society               Driving Under the Influence  ...  428
# 2  Crime Against Property                               Shoplifting  ...  271
# 3   Crime Against Society                 Trespass of Real Property  ...  321
# 4  Crime Against Property  Destruction/Damage/Vandalism of Property  ...  545
#
#   Address Number Street Prefix Street Name Street Suffix  Street Type  \
# 0         1700.0             E   JEFFERSON           NaN           ST
# 1          100.0             N   FREDERICK           NaN          AVE
# 2         5700.0           NaN         BOU           NaN          AVE
# 3        11100.0           NaN  VEIRS MILL           NaN           RD
# 4        18500.0             N   FREDERICK           NaN          AVE
#
#    Latitude Longitude Police District Number             Location
# 0  39.05848  -77.1264                     1D  (39.0585, -77.1264)
# 1  39.09438  -77.1517                     6D  (39.0944, -77.1517)
# 2  39.05597  -77.1136                     1D   (39.056, -77.1136)
# 3  39.03758  -77.0519                     4D  (39.0376, -77.0519)
# 4  39.16059  -77.2209                     6D  (39.1606, -77.2209)
#
# [5 rows x 30 columns]

# %%
dfCrime['Start_Date_Time'] = pd.to_datetime(dfCrime['Start_Date_Time'])
dfCrime.head()
# Out:
# /var/folders/6z/0pv81j2524v8c80qsmnrbmcm0000gn/T/ipykernel_18905/1499690141.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dfCrime['Start_Date_Time'] = pd.to_datetime(dfCrime['Start_Date_Time'])
#    Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0    201166610         2308  170548599                     NaN
# 1    201359823         5404  220000965  01/09/2022 01:18:38 AM
# 2    201095140         2303   16043118                     NaN
# 3    201090710         5707   16037677                     NaN
# 4    201362142         2901  220003839  01/28/2022 07:11:29 PM
#
#       Start_Date_Time           End_Date_Time NIBRS Code  Victims  \
# 0 2017-12-14 16:30:00                     NaN        23D        1
# 1 2022-01-09 01:34:00                     NaN        90D        1
# 2 2016-08-24 21:47:00                     NaN        23C        1
# 3 2016-07-25 17:31:00                     NaN        90J        1
# 4 2022-01-28 14:40:00  01/28/2022 02:46:00 PM        290        1
#
#               Crime Name1                               Crime Name2  ...  PRA  \
# 0  Crime Against Property                       Theft from Building  ...  270
# 1   Crime Against Society               Driving Under the Influence  ...  428
# 2  Crime Against Property                               Shoplifting  ...  271
# 3   Crime Against Society                 Trespass of Real Property  ...  321
# 4  Crime Against Property  Destruction/Damage/Vandalism of Property  ...  545
#
#   Address Number Street Prefix Street Name Street Suffix  Street Type  \
# 0         1700.0             E   JEFFERSON           NaN           ST
# 1          100.0             N   FREDERICK           NaN          AVE
# 2         5700.0           NaN         BOU           NaN          AVE
# 3        11100.0           NaN  VEIRS MILL           NaN           RD
# 4        18500.0             N   FREDERICK           NaN          AVE
#
#    Latitude Longitude Police District Number             Location
# 0  39.05848  -77.1264                     1D  (39.0585, -77.1264)
# 1  39.09438  -77.1517                     6D  (39.0944, -77.1517)
# 2  39.05597  -77.1136                     1D   (39.056, -77.1136)
# 3  39.03758  -77.0519                     4D  (39.0376, -77.0519)
# 4  39.16059  -77.2209                     6D  (39.1606, -77.2209)
#
# [5 rows x 30 columns]

# %%
dfCrime = dfCrime.loc[(dfCrime['Start_Date_Time'] >= '2019-01-01') & (dfCrime['Start_Date_Time'] < '2020-01-01')]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (52644, 30)
#     Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 10    201225360         2204  190004807  01/30/2019 07:49:25 PM
# 32    201228679         3562  190009437  02/27/2019 10:42:38 PM
# 35    201228679         5212  190009437  02/27/2019 10:42:38 PM
# 50    201231950         3560  190013370  03/23/2019 02:01:51 AM
# 74    201226430         2305  190006652  02/11/2019 10:16:59 AM
#
#        Start_Date_Time End_Date_Time NIBRS Code  Victims  \
# 10 2019-01-30 19:49:00           NaN        220        1
# 32 2019-02-27 22:42:00           NaN        35A        1
# 35 2019-02-27 22:42:00           NaN        520        1
# 50 2019-03-23 02:02:00           NaN        35A        1
# 74 2019-02-11 10:12:00           NaN        23F        1
#
#                Crime Name1                     Crime Name2  ...  PRA  \
# 10  Crime Against Property  Burglary/Breaking and Entering  ...  145
# 32   Crime Against Society        Drug/Narcotic Violations  ...  094
# 35   Crime Against Society           Weapon Law Violations  ...  094
# 50   Crime Against Society        Drug/Narcotic Violations  ...  012
# 74  Crime Against Property        Theft From Motor Vehicle  ...  095
#
#    Address Number Street Prefix Street Name Street Suffix  Street Type  \
# 10        11500.0           NaN    LOCKWOOD           NaN           DR
# 32            NaN           NaN     GEORGIA           NaN          AVE
# 35            NaN           NaN     GEORGIA           NaN          AVE
# 50            NaN           NaN    SHEPHERD           NaN           ST
# 74         1100.0           NaN      FIDLER           NaN           LA
#
#     Latitude Longitude Police District Number             Location
# 10  39.04120  -76.9862                     3D  (39.0412, -76.9862)
# 32  39.11237  -77.0755                     3D  (39.1124, -77.0755)
# 35  39.11237  -77.0755                     3D  (39.1124, -77.0755)
# 50  38.97953  -77.0707                     2D  (38.9795, -77.0707)
# 74  38.99700  -77.0292                     3D   (38.997, -77.0292)
#
# [5 rows x 30 columns]

# %%
list(dfCrime['Crime Name2'].unique())
# Out:
# ['Burglary/Breaking and Entering',
#  'Drug/Narcotic Violations',
#  'Weapon Law Violations',
#  'Theft From Motor Vehicle',
#  'Destruction/Damage/Vandalism of Property',
#  'Liquor Law Violations',
#  'Disorderly Conduct',
#  'Shoplifting',
#  'Simple Assault',
#  'Driving Under the Influence',
#  'Theft from Building',
#  'Trespass of Real Property',
#  'All other Larceny',
#  'Identity Theft',
#  'Prostitution',
#  'Assisting or Promoting Prostitution',
#  'Aggravated Assault',
#  'Forcible Rape',
#  'Counterfeiting/Forgery',
#  'Forcible Fondling',
#  'False Pretenses/Swindle/Confidence Game',
#  'Stolen Property Offenses',
#  'All Other Offenses',
#  'Theft of Motor Vehicle Parts or Accessories',
#  'Intimidation',
#  'Family Offenses, NonViolent',
#  'Robbery',
#  'Arson',
#  'Credit Card/Automatic Teller Machine Fraud',
#  'Motor Vehicle Theft',
#  'Drug Equipment Violations',
#  'Statuory Rape',
#  'Extortion/Blackmail',
#  'Impersonation',
#  'Pocket/picking',
#  'Purse-snatching',
#  'Pornography/Obscene Material',
#  'Embezzlement',
#  'Wire Fraud',
#  'Animal Cruelty',
#  'Kidnapping/Abduction',
#  'Murder and Nonnegligent Manslaughter',
#  'Human Trafficking, Commercial Sex Acts',
#  'Incest',
#  'From Coin/Operated Machine or Device',
#  'Curfew/Loitering/Vagrancy Violations',
#  'Welfare Fraud',
#  'Runaway',
#  'Justifiable Homicide']

# %%
violentCrimes = ['Robbery', 'Aggravated Assault', 'Forcible Rape', 'Murder and Nonnegligent Manslaughter', 'Human Trafficking, Commercial Sex Acts']
propertyCrimes = ['Burglary/Breaking and Entering', 'Theft From Motor Vehicle', 'Theft from Building', 'All other Larceny', 
                  'Stolen Property Offenses', 'Theft of Motor Vehicle Parts or Accessories', 'Motor Vehicle Theft']
both = violentCrimes + propertyCrimes
dfCrime = dfCrime[dfCrime['Crime Name2'].isin(both)]
dfCrime = dfCrime[['Crime Name2', 'Longitude', 'Latitude']]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (13414, 3)
#                         Crime Name2  Longitude  Latitude
# 10   Burglary/Breaking and Entering   -76.9862  39.04120
# 74         Theft From Motor Vehicle   -77.0292  38.99700
# 462             Theft from Building   -77.0519  39.03758
# 503        Theft From Motor Vehicle   -76.9844  39.06758
# 539             Theft from Building   -77.0244  38.99540

# %%
# make our lon and lat into a point type for spacial join
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
dfCrime = dfCrime[['Crime Name2', 'geometry']]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (13414, 2)
#                         Crime Name2                             geometry
# 10   Burglary/Breaking and Entering             POINT (-76.9862 39.0412)
# 74         Theft From Motor Vehicle              POINT (-77.0292 38.997)
# 462             Theft from Building            POINT (-77.0519 39.03758)
# 503        Theft From Motor Vehicle  POINT (-76.98439999999999 39.06758)
# 539             Theft from Building             POINT (-77.0244 38.9954)

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("/Users/austincoffelt/Documents/Rent-Walk-Local/cb_2018_24_bg_500k/cb_2018_24_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (3916, 11)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      24      047  980000        1  1500000US240479800001  240479800001    1
# 1      24      019  970900        2  1500000US240199709002  240199709002    2
# 2      24      003  706302        3  1500000US240037063023  240037063023    3
# 3      24      027  606606        1  1500000US240276066061  240276066061    1
# 4      24      005  491201        1  1500000US240054912011  240054912011    1
#
#   LSAD      ALAND     AWATER  \
# 0   BG   36014136  196706380
# 1   BG  264765218  196678699
# 2   BG     500847     785990
# 3   BG     709671          0
# 4   BG    1126592          0
#
#                                             geometry
# 0  POLYGON ((-75.379 38.025, -75.378 38.026, -75....
# 1  MULTIPOLYGON (((-76.065 38.13, -76.065 38.13, ...
# 2  POLYGON ((-76.486 38.973, -76.481 38.977, -76....
# 3  POLYGON ((-76.823 39.213, -76.822 39.213, -76....
# 4  POLYGON ((-76.588 39.402, -76.585 39.402, -76....

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#                         Crime Name2                geometry
# 10   Burglary/Breaking and Entering  POINT (-76.986 39.041)
# 74         Theft From Motor Vehicle  POINT (-77.029 38.997)
# 462             Theft from Building  POINT (-77.052 39.038)
# 503        Theft From Motor Vehicle  POINT (-76.984 39.068)
# 539             Theft from Building  POINT (-77.024 38.995)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (13414, 13)
#                         Crime Name2                geometry  index_right  \
# 10   Burglary/Breaking and Entering  POINT (-76.986 39.041)        709.0
# 74         Theft From Motor Vehicle  POINT (-77.029 38.997)       1128.0
# 462             Theft from Building  POINT (-77.052 39.038)       1510.0
# 503        Theft From Motor Vehicle  POINT (-76.984 39.068)        786.0
# 539             Theft from Building  POINT (-77.024 38.995)       3020.0
#
#     STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID  \
# 10       24      031  701509        3  1500000US240317015093  240317015093
# 74       24      031  702500        2  1500000US240317025002  240317025002
# 462      24      031  703800        1  1500000US240317038001  240317038001
# 503      24      031  701415        4  1500000US240317014154  240317014154
# 539      24      031  702402        2  1500000US240317024022  240317024022
#
#     NAME LSAD      ALAND   AWATER
# 10     3   BG   271849.0      0.0
# 74     2   BG    81893.0      0.0
# 462    1   BG  1215015.0    210.0
# 503    4   BG   729256.0  10704.0
# 539    2   BG   157119.0      0.0

# %%
crime = result['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US240317038001    350
# 1500000US240317025001    324
# 1500000US240317025004    168
# 1500000US240317024023    143
# 1500000US240317003092    125
#                         ...
# 1500000US240317053002      1
# 1500000US240317057021      1
# 1500000US240317012161      1
# 1500000US240338059061      1
# 1500000US240317006043      1
# Name: count, Length: 613, dtype: int64

# %%
crime.to_csv('/Users/austincoffelt/Documents/RW Data/MontMD_all_crime_by_BG.csv')

# %%
result2 = result[result['Crime Name2'].isin(violentCrimes)]
crime = result2['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US240317038001    68
# 1500000US240317007132    36
# 1500000US240317025004    32
# 1500000US240317025001    29
# 1500000US240317003092    25
#                          ..
# 1500000US240317032212     1
# 1500000US240317045022     1
# 1500000US240317012053     1
# 1500000US240317007102     1
# 1500000US240317014151     1
# Name: count, Length: 407, dtype: int64

# %%
crime.to_csv('/Users/austincoffelt/Documents/RW Data/MontMD_violent_crime_by_BG.csv')

# %%
result3 = result[result['Crime Name2'].isin(propertyCrimes)]
crime = result3['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US240317025001    295
# 1500000US240317038001    282
# 1500000US240317025004    136
# 1500000US240317024023    126
# 1500000US240317003092    100
#                         ...
# 1500000US240317057021      1
# 1500000US240317047004      1
# 1500000US240317032181      1
# 1500000US240317013044      1
# 1500000US240317006043      1
# Name: count, Length: 611, dtype: int64

# %%
crime.to_csv('/Users/austincoffelt/Documents/RW Data/MontMD_property_crime_by_BG.csv')

# %%
result4 = result[result['Crime Name2'].isin(['Motor Vehicle Theft'])]
crime = result4['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US240317025001    27
# 1500000US240317038001    16
# 1500000US240317024023    15
# 1500000US240317012111    10
# 1500000US240317007042     9
#                          ..
# 1500000US240317014151     1
# 1500000US240317044043     1
# 1500000US240317012011     1
# 1500000US240317003041     1
# 1500000US240317040002     1
# Name: count, Length: 357, dtype: int64

# %%
crime.to_csv('/Users/austincoffelt/Documents/RW Data/MontMD_mv_crime_by_BG.csv')
