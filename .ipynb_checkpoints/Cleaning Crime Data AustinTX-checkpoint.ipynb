# %%
import pandas as pd
import numpy as np

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Downloads/Rent-Walk-Local/Crime_Reports.csv')
print(dfCrime.shape)
dfCrime.head()
# Out:
# (2613106, 19)
#    Incident Number Highest Offense Description  Highest Offense Code  \
# 0       2006761045           CRIMINAL MISCHIEF                  1400
# 1       2006761134         PUBLIC INTOXICATION                  2300
# 2       2006691217                       THEFT                   600
# 3      20065014461                  HARASSMENT                  2703
# 4       2006692344                       THEFT                   600
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N  03/17/2006  13:06    03/17/2006         1306.0
# 1               N  03/17/2006  14:10    03/17/2006         1410.0
# 2               N  03/10/2006  14:15    03/10/2006         1415.0
# 3               N  10/01/2005  08:00    10/01/2005          800.0
# 4               N  02/09/2006  22:39    02/09/2006         2239.0
#
#     Report Date Time Report Date  Report Time  \
# 0  03/17/2006  13:06  03/17/2006       1306.0
# 1  03/17/2006  14:10  03/17/2006       1410.0
# 2  03/10/2006  14:30  03/10/2006       1430.0
# 3  03/21/2006  10:50  03/21/2006       1050.0
# 4  02/09/2006  22:39  02/09/2006       2239.0
#
#                           Location Type  Council District APD Sector  \
# 0                      RESIDENCE / HOME               NaN         88
# 1  HWY / ROAD / ALLEY/ STREET/ SIDEWALK               NaN         GE
# 2                 GROCERY / SUPERMARKET               5.0         FR
# 3                      RESIDENCE / HOME               5.0         DA
# 4                      RESIDENCE / HOME               2.0         FR
#
#   APD District Clearance Status Clearance Date UCR Category  \
# 0           88              NaN            NaN          NaN
# 1            3              NaN            NaN          NaN
# 2            1              NaN            NaN          23H
# 3            3              NaN     03/31/2006          NaN
# 4            8                N     03/21/2006          23H
#
#   Category Description  Census Block Group
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                Theft        4.530318e+09
# 3                  NaN        4.530020e+09
# 4                Theft        4.530024e+09

# %%
dfCrime['Occurred Date'] = pd.to_datetime(dfCrime['Occurred Date'])
dfCrime.head()
# Out:
#    Incident Number Highest Offense Description  Highest Offense Code  \
# 0       2006761045           CRIMINAL MISCHIEF                  1400
# 1       2006761134         PUBLIC INTOXICATION                  2300
# 2       2006691217                       THEFT                   600
# 3      20065014461                  HARASSMENT                  2703
# 4       2006692344                       THEFT                   600
#
#   Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 0               N  03/17/2006  13:06    2006-03-17         1306.0
# 1               N  03/17/2006  14:10    2006-03-17         1410.0
# 2               N  03/10/2006  14:15    2006-03-10         1415.0
# 3               N  10/01/2005  08:00    2005-10-01          800.0
# 4               N  02/09/2006  22:39    2006-02-09         2239.0
#
#     Report Date Time Report Date  Report Time  \
# 0  03/17/2006  13:06  03/17/2006       1306.0
# 1  03/17/2006  14:10  03/17/2006       1410.0
# 2  03/10/2006  14:30  03/10/2006       1430.0
# 3  03/21/2006  10:50  03/21/2006       1050.0
# 4  02/09/2006  22:39  02/09/2006       2239.0
#
#                           Location Type  Council District APD Sector  \
# 0                      RESIDENCE / HOME               NaN         88
# 1  HWY / ROAD / ALLEY/ STREET/ SIDEWALK               NaN         GE
# 2                 GROCERY / SUPERMARKET               5.0         FR
# 3                      RESIDENCE / HOME               5.0         DA
# 4                      RESIDENCE / HOME               2.0         FR
#
#   APD District Clearance Status Clearance Date UCR Category  \
# 0           88              NaN            NaN          NaN
# 1            3              NaN            NaN          NaN
# 2            1              NaN            NaN          23H
# 3            3              NaN     03/31/2006          NaN
# 4            8                N     03/21/2006          23H
#
#   Category Description  Census Block Group
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                Theft        4.530318e+09
# 3                  NaN        4.530020e+09
# 4                Theft        4.530024e+09

# %%
dfCrime = dfCrime.loc[(dfCrime['Occurred Date'] >= '2018-01-01') & (dfCrime['Occurred Date'] < '2019-01-01')]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (99466, 19)
#          Incident Number    Highest Offense Description  Highest Offense Code  \
# 1925137        201810424            PUBLIC INTOXICATION                  2300
# 1925139        201810274  AGG ASSAULT FAM/DATE VIOLENCE                   402
# 1925140        201810399    VIOL CITY ORDINANCE - OTHER                  3299
# 1925142        201810283            PUBLIC INTOXICATION                  2300
# 1925143        201810304    AGG ASLT STRANGLE/SUFFOCATE                   410
#
#         Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 1925137               N  01/01/2018  02:08    2018-01-01          208.0
# 1925139               Y  01/01/2018  01:12    2018-01-01          112.0
# 1925140               N  01/01/2018  01:55    2018-01-01          155.0
# 1925142               N  01/01/2018  03:08    2018-01-01          308.0
# 1925143               Y  01/01/2018  01:19    2018-01-01          119.0
#
#           Report Date Time Report Date  Report Time  \
# 1925137  01/01/2018  02:08  01/01/2018        208.0
# 1925139  01/01/2018  02:58  01/01/2018        258.0
# 1925140  01/01/2018  01:57  01/01/2018        157.0
# 1925142  01/01/2018  03:08  01/01/2018        308.0
# 1925143  01/01/2018  01:19  01/01/2018        119.0
#
#                                 Location Type  Council District APD Sector  \
# 1925137  HWY / ROAD / ALLEY/ STREET/ SIDEWALK               9.0         GE
# 1925139                      RESIDENCE / HOME               4.0         ED
# 1925140  HWY / ROAD / ALLEY/ STREET/ SIDEWALK               9.0         GE
# 1925142  HWY / ROAD / ALLEY/ STREET/ SIDEWALK               9.0         GE
# 1925143                  HOTEL / MOTEL / ETC.               9.0         GE
#
#         APD District Clearance Status Clearance Date UCR Category  \
# 1925137            2                C     01/01/2018          NaN
# 1925139            1                C     01/01/2018          13A
# 1925140            2                C     01/01/2018          NaN
# 1925142            2                C     01/01/2018          NaN
# 1925143            3                C     01/03/2018          13A
#
#         Category Description  Census Block Group
# 1925137                  NaN        4.530011e+09
# 1925139   Aggravated Assault        4.530400e+09
# 1925140                  NaN        4.530011e+09
# 1925142                  NaN        4.530011e+09
# 1925143   Aggravated Assault        4.530011e+09

# %%
list(dfCrime['Category Description'].unique())
# Out:
# [nan,
#  'Aggravated Assault',
#  'Burglary',
#  'Theft',
#  'Rape',
#  'Robbery',
#  'Auto Theft',
#  'Murder']

# %%
dfCrime = dfCrime[(dfCrime['Category Description'] == 'Aggravated Assault') |
                  (dfCrime['Category Description'] == 'Robbery') |
                  (dfCrime['Category Description'] == 'Rape') |
                  (dfCrime['Category Description'] == 'Murder')]
dfCrime.shape
# Out:
# (3825, 19)

# %%
dfCrime = dfCrime[dfCrime['Census Block Group'].isnull() == False]
dfCrime['Census Block Group'] = dfCrime['Census Block Group'].apply(lambda x: f"{x:.0f}")
dfCrime['Census Block Group'] = '48' + dfCrime['Census Block Group']
dfCrime['AFFGEOID'] = '1500000US' + dfCrime['Census Block Group']
print(dfCrime.shape)
dfCrime.head()
# Out:
# (3773, 20)
#          Incident Number    Highest Offense Description  Highest Offense Code  \
# 1925139        201810274  AGG ASSAULT FAM/DATE VIOLENCE                   402
# 1925143        201810304    AGG ASLT STRANGLE/SUFFOCATE                   410
# 1925144        201810407                    AGG ASSAULT                   402
# 1925199        201810858  AGG ASSAULT FAM/DATE VIOLENCE                   402
# 1925232        201811554  AGG ASSAULT FAM/DATE VIOLENCE                   402
#
#         Family Violence Occurred Date Time Occurred Date  Occurred Time  \
# 1925139               Y  01/01/2018  01:12    2018-01-01          112.0
# 1925143               Y  01/01/2018  01:19    2018-01-01          119.0
# 1925144               N  01/01/2018  03:03    2018-01-01          303.0
# 1925199               Y  01/01/2018  05:38    2018-01-01          538.0
# 1925232               Y  01/01/2018  18:30    2018-01-01         1830.0
#
#           Report Date Time Report Date  Report Time         Location Type  \
# 1925139  01/01/2018  02:58  01/01/2018        258.0      RESIDENCE / HOME
# 1925143  01/01/2018  01:19  01/01/2018        119.0  HOTEL / MOTEL / ETC.
# 1925144  01/01/2018  03:03  01/01/2018        303.0       BAR / NIGHTCLUB
# 1925199  01/01/2018  05:38  01/01/2018        538.0      RESIDENCE / HOME
# 1925232  01/01/2018  19:11  01/01/2018       1911.0      RESIDENCE / HOME
#
#          Council District APD Sector APD District Clearance Status  \
# 1925139               4.0         ED            1                C
# 1925143               9.0         GE            3                C
# 1925144               9.0         GE            1                N
# 1925199               2.0         FR            7                C
# 1925232               2.0         FR            5                C
#
#         Clearance Date UCR Category Category Description Census Block Group  \
# 1925139     01/01/2018          13A   Aggravated Assault       484530400003
# 1925143     01/03/2018          13A   Aggravated Assault       484530011032
# 1925144     02/08/2018          13A   Aggravated Assault       484530011021
# 1925199     01/01/2018          13A   Aggravated Assault       484530024511
# 1925232     01/01/2018          13A   Aggravated Assault       484530024132
#
#                       AFFGEOID
# 1925139  1500000US484530400003
# 1925143  1500000US484530011032
# 1925144  1500000US484530011021
# 1925199  1500000US484530024511
# 1925232  1500000US484530024132

# %%
crime = dfCrime['AFFGEOID'].value_counts()
crime = pd.DataFrame(crime)
print(crime.shape)
crime.head()
# Out:
# (549, 1)
#                        count
# AFFGEOID
# 1500000US484530011011    134
# 1500000US484530011032     39
# 1500000US484530009024     39
# 1500000US484530023161     38
# 1500000US484530407003     37

# %%
crime.to_csv('AustinTX_violent_crime_by_BG.csv')
