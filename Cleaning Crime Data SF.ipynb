# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from shapely.geometry import Point

# %%
dfCrime = pd.read_csv('/Users/austincoffelt/Documents/Rent-Walk-Local/Police_Department_Incident_Reports__2018_to_Present_20250412.csv')
print(dfCrime.shape)
dfCrime.head()
# Out:
# (947910, 35)
#         Incident Datetime Incident Date Incident Time  Incident Year  \
# 0  2023/03/01 05:02:00 AM    2023/03/01         05:02           2023
# 1  2023/03/13 10:59:00 AM    2023/03/13         10:59           2023
# 2  2023/03/14 06:44:00 PM    2023/03/14         18:44           2023
# 3  2023/02/15 03:00:00 AM    2023/02/15         03:00           2023
# 4  2023/03/11 03:00:00 PM    2023/03/11         15:00           2023
#
#   Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 0            Wednesday  2023/03/11 03:40:00 PM  125379506374      1253795
# 1               Monday  2023/03/13 11:00:00 AM  125355107041      1253551
# 2              Tuesday  2023/03/14 06:45:00 PM  125402407041      1254024
# 3            Wednesday  2023/03/11 04:55:00 PM  125378606372      1253786
# 4             Saturday  2023/03/13 08:29:00 AM  125420606244      1254206
#
#    Incident Number  CAD Number  ... Longitude Point Neighborhoods  \
# 0        236046151         NaN  ...       NaN   NaN           NaN
# 1        230174885         NaN  ...       NaN   NaN           NaN
# 2        230176728         NaN  ...       NaN   NaN           NaN
# 3        236046123         NaN  ...       NaN   NaN           NaN
# 4        236045937         NaN  ...       NaN   NaN           NaN
#
#    ESNCAG - Boundary File  \
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
#   Central Market/Tenderloin Boundary Polygon - Updated  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
#
#   Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    Current Police Districts
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 35 columns]

# %%
dfCrime = dfCrime[(dfCrime['Latitude'].isna() == False) & (dfCrime['Longitude'].isna() == False)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (896213, 35)
#           Incident Datetime Incident Date Incident Time  Incident Year  \
# 6    2022/06/27 12:00:00 PM    2022/06/27         12:00           2022
# 8    2023/03/16 05:30:00 PM    2023/03/16         17:30           2023
# 26   2023/03/21 03:50:00 PM    2023/03/21         15:50           2023
# 144  2021/07/03 12:00:00 PM    2021/07/03         12:00           2021
# 145  2021/07/22 07:16:00 PM    2021/07/22         19:16           2021
#
#     Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 6                 Monday  2023/03/15 05:20:00 PM  125439371000      1254393
# 8               Thursday  2023/03/16 06:02:00 PM  125482604134      1254826
# 26               Tuesday  2023/03/21 04:01:00 PM  125656351040      1256563
# 144             Saturday  2021/07/03 12:37:00 PM  104624471000      1046244
# 145             Thursday  2021/07/23 01:35:00 PM  105341571000      1053415
#
#      Incident Number   CAD Number  ...   Longitude  \
# 6          230184129  230742480.0  ... -122.408227
# 8          230187101  230752550.0  ... -122.401324
# 26         230199764  230802198.0  ... -122.418271
# 144        210417332  211841413.0  ... -122.446610
# 145        216098495          NaN  ... -122.394829
#
#                                               Point Neighborhoods  \
# 6     POINT (-122.40822672700406 37.78735926098589)          19.0
# 8     POINT (-122.40132418490647 37.76228996810526)          54.0
# 26   POINT (-122.41827098126804 37.787037946181535)          50.0
# 144  POINT (-122.44660957715965 37.801787342426636)          17.0
# 145   POINT (-122.39482876133759 37.76524759917852)          54.0
#
#      ESNCAG - Boundary File  \
# 6                       NaN
# 8                       NaN
# 26                      NaN
# 144                     NaN
# 145                     NaN
#
#     Central Market/Tenderloin Boundary Polygon - Updated  \
# 6                                                  1.0
# 8                                                  NaN
# 26                                                 NaN
# 144                                                NaN
# 145                                                NaN
#
#     Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 6                                            NaN                         NaN
# 8                                            NaN                         NaN
# 26                                           NaN                         NaN
# 144                                          NaN                         NaN
# 145                                          NaN                         NaN
#
#     Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 6                                   NaN                          3.0
# 8                                   NaN                          9.0
# 26                                  NaN                         10.0
# 144                                 NaN                          6.0
# 145                                 NaN                          9.0
#
#      Current Police Districts
# 6                         6.0
# 8                         2.0
# 26                        6.0
# 144                       4.0
# 145                       1.0
#
# [5 rows x 35 columns]

# %%
dfCrime = dfCrime[dfCrime['Incident Year'] == 2019]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (138391, 35)
#            Incident Datetime Incident Date Incident Time  Incident Year  \
# 200   2019/06/11 04:30:00 PM    2019/06/11         16:30           2019
# 790   2019/06/01 12:00:00 AM    2019/06/01         00:00           2019
# 3841  2019/04/01 12:00:00 AM    2019/04/01         00:00           2019
# 6261  2019/07/26 08:00:00 AM    2019/07/26         08:00           2019
# 6428  2019/02/06 06:00:00 PM    2019/02/06         18:00           2019
#
#      Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 200               Tuesday  2021/06/05 05:17:00 AM  103770002004      1037700
# 790              Saturday  2022/03/29 10:45:00 AM  113536668030      1135366
# 3841               Monday  2023/02/06 12:36:00 PM  125811771000      1258117
# 6261               Friday  2023/08/31 01:50:00 PM  131347507026      1313475
# 6428            Wednesday  2023/02/10 03:32:00 PM  125982406372      1259824
#
#       Incident Number   CAD Number  ...   Longitude  \
# 200         210348157  211560467.0  ... -122.408846
# 790         220204947  220881074.0  ... -122.391434
# 3841        236054370          NaN  ... -122.415291
# 6261        230622395  232430739.0  ... -122.404306
# 6428        236024323          NaN  ... -122.416401
#
#                                                Point Neighborhoods  \
# 200   POINT (-122.40884575063417 37.775953228502786)          32.0
# 790   POINT (-122.39143433652146 37.773466920607476)          34.0
# 3841   POINT (-122.41529083617453 37.71350427378473)          75.0
# 6261      POINT (-122.40430629342 37.74252073319404)          82.0
# 6428  POINT (-122.41640107183976 37.777722750028566)          21.0
#
#       ESNCAG - Boundary File  \
# 200                      NaN
# 790                      NaN
# 3841                     NaN
# 6261                     NaN
# 6428                     NaN
#
#      Central Market/Tenderloin Boundary Polygon - Updated  \
# 200                                                 NaN
# 790                                                 NaN
# 3841                                                NaN
# 6261                                                NaN
# 6428                                                1.0
#
#      Civic Center Harm Reduction Project Boundary HSOC Zones as of 2018-06-05  \
# 200                                           1.0                         1.0
# 790                                           NaN                         NaN
# 3841                                          NaN                         NaN
# 6261                                          NaN                         NaN
# 6428                                          1.0                         1.0
#
#      Invest In Neighborhoods (IIN) Areas Current Supervisor Districts  \
# 200                                  NaN                         10.0
# 790                                  NaN                         10.0
# 3841                                 NaN                          9.0
# 6261                                 NaN                          9.0
# 6428                                 NaN                         10.0
#
#       Current Police Districts
# 200                        1.0
# 790                        1.0
# 3841                       9.0
# 6261                       2.0
# 6428                       5.0
#
# [5 rows x 35 columns]

# %%
violentCrimes = ['Aggravated Assault', 'Rape - Attempted', 'Robbery - Residential', 'Robbery - Street', 'Robbery - Carjacking',
                'Sex Offense', 'Robbery - Commercial', 'Rape', 'Homicide', 'Robbery - Other']
dfCrime = dfCrime[dfCrime['Incident Subcategory'].isin(violentCrimes)]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (6663, 35)
#             Incident Datetime Incident Date Incident Time  Incident Year  \
# 200    2019/06/11 04:30:00 PM    2019/06/11         16:30           2019
# 21467  2019/05/05 12:00:00 AM    2019/05/05         00:00           2019
# 38663  2019/06/01 11:00:00 PM    2019/06/01         23:00           2019
# 59579  2019/11/21 01:20:00 AM    2019/11/21         01:20           2019
# 96916  2019/12/21 12:00:00 AM    2019/12/21         00:00           2019
#
#       Incident Day of Week         Report Datetime        Row ID  Incident ID  \
# 200                Tuesday  2021/06/05 05:17:00 AM  103770002004      1037700
# 21467               Sunday  2024/09/05 05:35:00 PM  142153502020      1421535
# 38663             Saturday  2023/05/30 10:17:00 PM  128090103074      1280901
# 59579             Thursday  2024/01/05 05:00:00 PM  135345804013      1353458
# 96916             Saturday  2024/06/20 10:00:00 AM  140016814020      1400168
#
#        Incident Number   CAD Number  ...   Longitude  \
# 200          210348157  211560467.0  ... -122.408846
# 21467        240559352  242492705.0  ... -122.481178
# 38663        230374289  231503362.0  ... -122.408189
# 59579        190880538          NaN  ... -122.414054
# 96916        240384870  241720966.0  ... -122.403633
#
#                                                 Point Neighborhoods  \
# 200    POINT (-122.40884575063417 37.775953228502786)          32.0
# 21467    POINT (-122.4811782836914 37.74468231201172)          40.0
# 38663   POINT (-122.40818896891844 37.75285240350464)          53.0
# 59579   POINT (-122.41405376568504 37.78279444506034)          20.0
# 96916   POINT (-122.40363311767578 37.77516174316406)          32.0
#
#        ESNCAG - Boundary File  \
# 200                       NaN
# 21467                     NaN
# 38663                     NaN
# 59579                     NaN
# 96916                     NaN
#
#       Central Market/Tenderloin Boundary Polygon - Updated  \
# 200                                                  NaN
# 21467                                                NaN
# 38663                                                NaN
# 59579                                                1.0
# 96916                                                NaN
#
#       Civic Center Harm Reduction Project Boundary  \
# 200                                            1.0
# 21467                                          NaN
# 38663                                          NaN
# 59579                                          1.0
# 96916                                          NaN
#
#       HSOC Zones as of 2018-06-05 Invest In Neighborhoods (IIN) Areas  \
# 200                           1.0                                 NaN
# 21467                         NaN                                 NaN
# 38663                         3.0                                 NaN
# 59579                         1.0                                 NaN
# 96916                         NaN                                 NaN
#
#       Current Supervisor Districts  Current Police Districts
# 200                           10.0                       1.0
# 21467                          7.0                      10.0
# 38663                          2.0                       3.0
# 59579                         10.0                       5.0
# 96916                         10.0                       1.0
#
# [5 rows x 35 columns]

# %%
dfCrime = dfCrime[['Incident ID', 'Longitude', 'Latitude']]
dfCrime.head()
# Out:
#        Incident ID   Longitude   Latitude
# 200        1037700 -122.408846  37.775953
# 21467      1421535 -122.481178  37.744682
# 38663      1280901 -122.408189  37.752852
# 59579      1353458 -122.414054  37.782794
# 96916      1400168 -122.403633  37.775162

# %%
# make our lon and lat into a point type for spacial join
dfCrime['geometry'] = dfCrime.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
dfCrime = dfCrime[['Incident ID', 'geometry']]
print(dfCrime.shape)
dfCrime.head()
# Out:
# (6663, 2)
#        Incident ID                                      geometry
# 200        1037700  POINT (-122.4088457506342 37.77595322850279)
# 21467      1421535  POINT (-122.4811782836914 37.74468231201172)
# 38663      1280901  POINT (-122.4081889689184 37.75285240350464)
# 59579      1353458   POINT (-122.414053765685 37.78279444506034)
# 96916      1400168  POINT (-122.4036331176758 37.77516174316406)

# %%
# Read shapefile (automatically loads .shp, .shx, .dbf)
gdf = gpd.read_file("/Users/austincoffelt/Documents/Rent-Walk-Local/cb_2018_06_bg_500k/cb_2018_06_bg_500k.shp")

# View the first 5 rows
print(gdf.shape)
gdf.head()
# Out:
# (23196, 11)
#   STATEFP COUNTYFP TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME  \
# 0      06      075  980401        1  1500000US060759804011  060759804011    1
# 1      06      059  062702        1  1500000US060590627021  060590627021    1
# 2      06      037  576602        1  1500000US060375766021  060375766021    1
# 3      06      075  061500        6  1500000US060750615006  060750615006    6
# 4      06      049  000300        2  1500000US060490003002  060490003002    2
#
#   LSAD       ALAND     AWATER  \
# 0   BG      419323  247501289
# 1   BG      513205     635569
# 2   BG      246841    1907927
# 3   BG      313325     229501
# 4   BG  1781768492  310119189
#
#                                             geometry
# 0  POLYGON ((-123.01 37.7, -123.01 37.699, -123.0...
# 1  POLYGON ((-117.88 33.593, -117.88 33.595, -117...
# 2  MULTIPOLYGON (((-118.18 33.765, -118.17 33.765...
# 3  POLYGON ((-122.39 37.783, -122.39 37.787, -122...
# 4  POLYGON ((-120.82 41.994, -120.79 41.994, -120...

# %%
# make sure points match the crs of gdf
gdfPoints = gpd.GeoDataFrame(
    dfCrime, 
    geometry='geometry',
    crs="EPSG:4269"  # WGS84 coordinate reference system
)
gdfPoints.head()
# Out:
#        Incident ID                geometry
# 200        1037700  POINT (-122.41 37.776)
# 21467      1421535  POINT (-122.48 37.745)
# 38663      1280901  POINT (-122.41 37.753)
# 59579      1353458  POINT (-122.41 37.783)
# 96916      1400168   POINT (-122.4 37.775)

# %%
# Basic spatial join (points within polygons)
result = gpd.sjoin(
    gdfPoints, 
    gdf,
    how="left",       # 'left', 'right', or 'inner'
    predicate="within" # Spatial relationship
)
print(result.shape)
result.head()
# Out:
# (6663, 13)
#        Incident ID                geometry  index_right STATEFP COUNTYFP  \
# 200        1037700  POINT (-122.41 37.776)        11436      06      075
# 21467      1421535  POINT (-122.48 37.745)         6835      06      075
# 38663      1280901  POINT (-122.41 37.753)        14539      06      075
# 59579      1353458  POINT (-122.41 37.783)        21414      06      075
# 96916      1400168   POINT (-122.4 37.775)        10013      06      075
#
#       TRACTCE BLKGRPCE               AFFGEOID         GEOID NAME LSAD   ALAND  \
# 200    017802        1  1500000US060750178021  060750178021    1   BG  320288
# 21467  032801        3  1500000US060750328013  060750328013    3   BG  235236
# 38663  022903        1  1500000US060750229031  060750229031    1   BG   88035
# 59579  012502        2  1500000US060750125022  060750125022    2   BG   30632
# 96916  018000        2  1500000US060750180002  060750180002    2   BG  509339
#
#        AWATER
# 200         0
# 21467       0
# 38663       0
# 59579       0
# 96916       0

# %%
crime = result['AFFGEOID'].value_counts()
crime
# Out:
# AFFGEOID
# 1500000US060750117002    205
# 1500000US060750615001    200
# 1500000US060750176015    178
# 1500000US060750125012    138
# 1500000US060750176013    123
#                         ...
# 1500000US060750478023      1
# 1500000US060750352013      1
# 1500000US060750328022      1
# 1500000US060750326012      1
# 1500000US060750168023      1
# Name: count, Length: 486, dtype: int64

# %%
# export as a csv
crime.to_csv('/Users/austincoffelt/Documents/RW Data/SF_Violent_Crime_BG.csv')
